# %%
from scipy.spatial import distance_matrix
import numpy as np
import matplotlib.pyplot as plt
import random
import math
import time
import pandas as pd

dataset_name = 'rc101'
file_path = '../Dataset/'+dataset_name+'.txt'

# Initialize lists to store vehicle and customer data
vehicle_data = []
customer_data = []

# Read data line by line
with open(file_path, 'r') as file:
    lines = file.readlines()
    
    # Parse vehicle data
    vehicle_info_start = lines.index('VEHICLE\n') + 2
    customer_info_start = lines.index('CUSTOMER\n') + 2
    vehicle_line = lines[vehicle_info_start].strip().split()
    
    # Store vehicle data as a dictionary in a list
    vehicle_data.append({
        'NUMBER': int(vehicle_line[0]),
        'CAPACITY': int(vehicle_line[1])
    })
    
    # Parse customer data
    for line in lines[customer_info_start:]:
        if line.strip():  # Skip any empty lines
            parts = line.strip().split()
            customer_data.append({
                'CUST_NO': int(parts[0]),
                'XCOORD': int(parts[1]),
                'YCOORD': int(parts[2]),
                'DEMAND': int(parts[3]),
                'READY_TIME': int(parts[4]),
                'DUE_DATE': int(parts[5]),
                'SERVICE_TIME': int(parts[6])
            })

# %%
class Node:
    def __init__(self, id, x, y, demand, ready_time, due_date, service_time):
        self.id = id
        self.is_depot = (id == 0)
        self.x = x
        self.y = y
        self.demand = demand
        self.ready_time = ready_time
        self.due_date = due_date
        self.service_time = service_time
        self.service_time = 10
        self.visited = False
        
class Graph:
    def __init__(self, vehicle_data, customer_data):
        self.vehicle_data = vehicle_data
        self.customer_data = customer_data
        self.nodes = []
        self.vehicle_capacity = vehicle_data[0]['CAPACITY']
        self.num_vehicles = vehicle_data[0]['NUMBER']
        self.setup_nodes()
        self.setup_distance_matrix()
        self.initialize_pheromone_matrix()
        
    def setup_nodes(self):
        for customer in self.customer_data:
            node = Node(customer['CUST_NO'], customer['XCOORD'], customer['YCOORD'], customer['DEMAND'],
                        customer['READY_TIME'], customer['DUE_DATE'], customer['SERVICE_TIME'])
            self.nodes.append(node)
    
    def setup_distance_matrix(self):
        coords = [(node.x, node.y) for node in self.nodes]
        self.distance_matrix = distance_matrix(coords, coords)
        
    def initialize_pheromone_matrix(self):
        n = len(self.nodes)
        self.pheromone_matrix = [[1.0 for _ in range(n)] for _ in range(n)]
    
    def route_distance(self, route):
        distance = 0
        for i in range(len(route) - 1):
            distance += self.distance_matrix[route[i]][route[i + 1]]
        return distance
    
    def update_pheromones(self, ant_solutions, evaporation_rate=0.5):
        # Evaporate pheromones
        for i in range(len(self.pheromone_matrix)):
            for j in range(len(self.pheromone_matrix)):
                self.pheromone_matrix[i][j] = max(self.pheromone_matrix[i][j] * (1 - evaporation_rate), 1e-5)

        
        # Deposit pheromones based on ant solutions
        total_distance = sum(self.route_distance(route) for solution in ant_solutions for route in solution)
        for route in ant_solutions:
            for k in range(len(route) - 1):
                i, j = route[k], route[k + 1]
                self.pheromone_matrix[i][j] += (1 / self.route_distance(route)) / total_distance

# %%
def aco_vrp(G, num_ants, num_iterations, alpha=1.5, beta=2.5, evaporation_rate=0.5, q=100):
    """
    Ant Colony Optimization for Vehicle Routing Problem with Time Windows.
    """
    adj_matrix = G.distance_matrix
    capacity_max = G.vehicle_capacity
    num_points = adj_matrix.shape[0]
    ph_matrix = G.pheromone_matrix  # Initial pheromone matrix
    best_solution = None
    best_cost = float('inf')

    def calculate_probabilities(current_node, unvisited, current_time, current_capacity):
        """
        Calculate probabilities of moving to the next node considering time windows and capacity constraints.
        """
        attractiveness = []
        for neighbor in unvisited:
            travel_time = G.distance_matrix[current_node][neighbor]
            arrival_time = current_time + travel_time
            if (G.nodes[neighbor].demand + current_capacity <= capacity_max
                    and arrival_time <= G.nodes[neighbor].due_date):
                tau = ph_matrix[current_node][neighbor] ** alpha
                eta = (1.0 / G.distance_matrix[current_node][neighbor]) ** beta
                attractiveness.append(tau * eta)
            else:
                attractiveness.append(0)
        total = sum(attractiveness)
        if total == 0:  # Avoid division by zero
            return np.zeros(len(unvisited))
        return np.array(attractiveness) / total

    def construct_solution():
        routes = []
        back_time = []
        for node in G.nodes:
            node.visited = False

        while any(not node.visited for node in G.nodes[1:]):  # Exclude the depot
            current_node = 0  # Start at depot
            current_time = G.nodes[current_node].ready_time
            current_capacity = 0
            route = [current_node]

            while True:
                unvisited = [i for i in range(1, len(G.nodes)) if not G.nodes[i].visited]
                if not unvisited:
                    break

                probabilities = calculate_probabilities(current_node, unvisited, current_time, current_capacity)
                if not probabilities.any():  # No valid moves
                    break

                next_node = random.choices(unvisited, weights=probabilities)[0]
                travel_time = G.distance_matrix[current_node][next_node]
                arrival_time = current_time + travel_time

                # Validate constraints
                if (current_capacity + G.nodes[next_node].demand <= capacity_max
                        and arrival_time <= G.nodes[next_node].due_date):
                    if arrival_time < G.nodes[next_node].ready_time:
                        wait_time = G.nodes[next_node].ready_time - arrival_time
                    else:
                        wait_time = 0
                    current_time = arrival_time + wait_time + G.nodes[next_node].service_time
                    current_capacity += G.nodes[next_node].demand
                    route.append(next_node)
                    G.nodes[next_node].visited = True
                    current_node = next_node
                else:
                    break  # No valid moves; end route

            # Return to depot
            current_time = current_time + G.distance_matrix[route[-1]][0]
            route.append(0)
            routes.append(route)
            back_time.append(current_time)
        if current_time > G.nodes[0].due_date:
            print("invalide route")
        return (routes,back_time)

    def calculate_total_distance(route):
        """
        Calculate the total distance of a given route using the distance matrix.
        """
        total_distance = 0
        for i in range(len(route) - 1):
            current_node = route[i]
            next_node = route[i + 1]
            total_distance += G.distance_matrix[current_node][next_node]
        return total_distance

    
    def calculate_cost(routes):
        total_cost = 0
        num_vehicles = len(routes)
        if num_vehicles > G.num_vehicles:  # Penalty for exceeding vehicle limits
            total_cost += 10000 * (num_vehicles - G.num_vehicles)
        for route in routes:
            total_cost += calculate_total_distance(route)
        total_cost = total_cost + num_vehicles*1000
        return total_cost



    def update_pheromones(all_solutions, ph_matrix, evaporation_rate=0.5):
        # Evaporate pheromones
        for i in range(len(ph_matrix)):
            for j in range(len(ph_matrix[i])):
                ph_matrix[i][j] *= (1 - evaporation_rate)
                ph_matrix[i][j] = max(ph_matrix[i][j], 1e-5)  # Prevent near-zero pheromones

        # Deposit pheromones for each solution
        for solution in all_solutions:
            routes = solution  # Each solution is a list of routes
            for route in routes:
                route_distance = calculate_total_distance(route)
                pheromone_deposit = q / max(route_distance, 1e-5)  # Prevent division by zero
                for i in range(len(route) - 1):
                    a, b = route[i], route[i + 1]
                    ph_matrix[a][b] += pheromone_deposit
                    ph_matrix[b][a] = ph_matrix[a][b]  # Ensure symmetry



    # Main ACO loop
    best_length_table = []
    for iteration in range(num_iterations):
        all_solutions = []
        all_costs = []

        for _ in range(num_ants):
            solution = construct_solution()
            cost = calculate_cost(solution[0])
            all_solutions.append(solution[0])
            all_costs.append(cost)

            if cost < best_cost:
                best_cost = cost
                best_solution = solution

        if len(best_solution[0]) <= G.num_vehicles:
            best_length = best_cost - (len(best_solution[0])*1000)
        else:
            best_length = best_cost - (G.num_vehicles*1000) - (len(best_solution[0]) - G.num_vehicles)*10000
        # Update pheromones with all solutions
        update_pheromones(all_solutions, G.pheromone_matrix)
        best_length_table.append(best_length)
        print(f"Iteration {iteration + 1}/{num_iterations}: Best cost = {round(best_cost,2)}, Best length = {round(best_length,2)}, Latest back time = {round(max(best_solution[1]),2)}")
        

    return best_solution[0],best_length, best_cost, max(best_solution[1]), best_length_table

def plot_solution(graph, solution, filename):
    """
    Plot the solution of the VRP problem.
    Args:
        graph: Graph object containing node information.
        solution: List of routes (e.g., [[0, 1, 3, 0], [0, 2, 4, 0], ...]).
    """
    # Extract node coordinates
    x_coords = [node.x for node in graph.nodes]
    y_coords = [node.y for node in graph.nodes]

    # Create the plot
    plt.figure(figsize=(10, 8))

    # Plot all nodes
    plt.scatter(x_coords, y_coords, color="grey", label="Customers", marker=".", zorder=5)
    
    # Highlight the depot (node 0)
    plt.scatter(x_coords[0], y_coords[0], color="black", label="Depot", marker="D", zorder=5, s=100)

    # Annotate each node with its ID
    for node in graph.nodes:
        plt.text(node.x, node.y, f"{node.id}", fontsize=8, ha="right", va="bottom")

    # Plot each route
    for route in solution:
        route_coords_x = [x_coords[i] for i in route]
        route_coords_y = [y_coords[i] for i in route]
        plt.plot(route_coords_x, route_coords_y, label=f"Route {solution.index(route) + 1}")

    # Customize the plot
    plt.title("Vehicle Routing Problem Solution\n" + filename)
    plt.xlabel("X Coordinate")
    plt.ylabel("Y Coordinate")
    plt.legend()
    plt.grid()
    plt.show()

# %%
G = Graph(vehicle_data, customer_data)

print("Depot closing time: " + str(G.nodes[0].due_date))

# Run ACO
best_solution_data,best_length, best_cost,best_time, best_length_table = aco_vrp(
    G,
    num_ants=50, num_iterations=50, alpha=1, beta=1, evaporation_rate=0.9, q=100
)

print("\n-----------------------------------------------------------")
print("Best cost: " + str(best_cost), "\nBest length: " + str(best_length),"\nLatest back time: " + str(best_time), " \nNumber of vehicle: " + str(len(best_solution_data)))
print("-----------------------------------------------------------\n")

i = 1
for route in best_solution_data:
    print("Route " + str(i) + ": " + str(route))
    i = i + 1

# Call the plotting function with the best solution
plot_solution(G, best_solution_data, dataset_name)
# Out:
# Depot closing time: 240
# Iteration 1/50: Best cost = 116588.57, Best length = 11588.57, Latest back time = 237.11
# Iteration 2/50: Best cost = 49678.07, Best length = 4678.07, Latest back time = 238.68
# Iteration 3/50: Best cost = 27529.77, Best length = 2529.77, Latest back time = 232.15
# Iteration 4/50: Best cost = 27529.77, Best length = 2529.77, Latest back time = 232.15
# Iteration 5/50: Best cost = 27529.77, Best length = 2529.77, Latest back time = 232.15
# Iteration 6/50: Best cost = 27529.77, Best length = 2529.77, Latest back time = 232.15
# Iteration 7/50: Best cost = 27529.77, Best length = 2529.77, Latest back time = 232.15
# Iteration 8/50: Best cost = 27465.88, Best length = 2465.88, Latest back time = 237.06
# Iteration 9/50: Best cost = 26496.14, Best length = 2496.14, Latest back time = 227.96
# Iteration 10/50: Best cost = 26496.14, Best length = 2496.14, Latest back time = 227.96
# Iteration 11/50: Best cost = 25334.39, Best length = 2334.39, Latest back time = 232.61
# Iteration 12/50: Best cost = 25334.39, Best length = 2334.39, Latest back time = 232.61
# Iteration 13/50: Best cost = 25334.39, Best length = 2334.39, Latest back time = 232.61
# Iteration 14/50: Best cost = 25334.39, Best length = 2334.39, Latest back time = 232.61
# Iteration 15/50: Best cost = 25334.39, Best length = 2334.39, Latest back time = 232.61
# Iteration 16/50: Best cost = 25334.39, Best length = 2334.39, Latest back time = 232.61
# Iteration 17/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 18/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 19/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 20/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 21/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 22/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 23/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 24/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 25/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 26/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 27/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 28/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 29/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 30/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 31/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 32/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 33/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 34/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 35/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 36/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 37/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 38/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 39/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 40/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 41/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 42/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 43/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 44/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 45/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 46/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 47/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 48/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 49/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
# Iteration 50/50: Best cost = 24448.16, Best length = 2448.16, Latest back time = 234.04
#
# -----------------------------------------------------------
# Best cost: 24448.156068766293
# Best length: 2448.156068766293
# Latest back time: 234.03663790919563
# Number of vehicle: 22
# -----------------------------------------------------------
#
# Route 1: [0, 90, 81, 54, 96, 91, 80, 0]
# Route 2: [0, 55, 68, 70, 100, 0]
# Route 3: [0, 53, 78, 60, 0]
# Route 4: [0, 69, 98, 88, 8, 46, 4, 1, 0]
# Route 5: [0, 2, 5, 7, 6, 3, 93, 0]
# Route 6: [0, 45, 73, 79, 17, 13, 0]
# Route 7: [0, 83, 75, 87, 10, 0]
# Route 8: [0, 95, 62, 19, 49, 20, 25, 24, 0]
# Route 9: [0, 92, 64, 51, 85, 84, 56, 66, 0]
# Route 10: [0, 71, 67, 94, 50, 0]
# Route 11: [0, 72, 39, 38, 44, 41, 37, 35, 0]
# Route 12: [0, 65, 23, 21, 18, 22, 48, 0]
# Route 13: [0, 52, 99, 57, 86, 74, 58, 0]
# Route 14: [0, 82, 12, 11, 9, 97, 77, 0]
# Route 15: [0, 61, 40, 43, 0]
# Route 16: [0, 59, 15, 16, 89, 0]
# Route 17: [0, 42, 36, 26, 32, 0]
# Route 18: [0, 47, 14, 0]
# Route 19: [0, 29, 31, 30, 34, 0]
# Route 20: [0, 63, 76, 0]
# Route 21: [0, 27, 28, 0]
# Route 22: [0, 33, 0]

# %% [markdown]
# # This solution above ...

# %%
print("Use "+str(len(best_solution_data))+" vehicles")
# Out:
# Use 23 vehicles

# %%
print("Has a total cost of: " + str(best_cost))
# Out:
# Has a total cost of: 25382.329087632224

# %% [markdown]
# While Total Cost represent 1 per distance unit, 1 000 per authorized vehicle, 10 000 per unavailable vehicle.

# %%
print("Has a latest back time of: " + str(best_time))
print("While the depot closing time is: " + str(G.nodes[0].due_date))
# Out:
# Has a latest back time of: 236.7558667943452
# While the depot closing time is: 240

# %%
print("Has a total distance of: " + str(best_length))
# Out:
# Has a total distance of: 2382.3290876322244

# %% [markdown]
# ### Experimental tests

# %%
j = []
k = [0.5, 1, 2, 5]
l = [1, 2, 5]
for index in range(5):
    j.append(index * 20 + 20)
    index = index + 1

test_max = len(j) * len(k) * len(l)
test = 0
best_solution_data = []
best_cost = []
best_time = []
execution_time = []
min = float("inf")
         
for ants in j:
    for alpha in k:
        for beta in l:
            print("-------------------------------------------------------")
            print("Test " + str(test + 1) + "/" + str(test_max) + " | Iteration with this parameters: num_ants = " + str(ants) + " alpha = " + str(alpha) + " beta = " + str(beta))
            start = time.time()
            a, b, d, c = aco_vrp(G, num_ants=ants, num_iterations=50, alpha=alpha, beta=beta, evaporation_rate=0.5, q=100)
            end = time.time()
            print("Computation time taken: " + str(end - start))
            execution_time.append(end - start)
            best_solution_data.append(a)
            best_cost.append(b)
            best_time.append(c)
            print("Best cost: " + str(best_cost[test]),"\nBest back time: " + str(best_time[test]), " \nNumber of vehicle: " + str(len(best_solution_data[test])))
            test = test + 1
            
for solution in best_solution_data:
    if len(solution) < min:
        min = len(solution)

print("Minimum number of vehicle: " + str(min))
# Out:
# -------------------------------------------------------
# Test 1/60 | Iteration with this parameters: num_ants = 20 alpha = 0.5 beta = 1
# Computation time taken: 7.756594896316528
# Best cost: 2602.4190857166905
# Best back time: 234.78960507668654
# Number of vehicle: 24
# -------------------------------------------------------
# Test 2/60 | Iteration with this parameters: num_ants = 20 alpha = 0.5 beta = 2
# Computation time taken: 7.941118001937866
# Best cost: 2577.7577698821588
# Best back time: 237.83864693871914
# Number of vehicle: 24
# -------------------------------------------------------
# Test 3/60 | Iteration with this parameters: num_ants = 20 alpha = 0.5 beta = 5
# Computation time taken: 7.884934186935425
# Best cost: 2335.888496383104
# Best back time: 229.103619802453
# Number of vehicle: 22
# -------------------------------------------------------
# Test 4/60 | Iteration with this parameters: num_ants = 20 alpha = 1 beta = 1
# Computation time taken: 7.677469253540039
# Best cost: 2250.2072396591284
# Best back time: 227.44245075128353
# Number of vehicle: 22
# -------------------------------------------------------
# Test 5/60 | Iteration with this parameters: num_ants = 20 alpha = 1 beta = 2
# Computation time taken: 7.289480209350586
# Best cost: 2409.7201804727774
# Best back time: 237.72711562230543
# Number of vehicle: 23
# -------------------------------------------------------
# Test 6/60 | Iteration with this parameters: num_ants = 20 alpha = 1 beta = 5
# Computation time taken: 7.298482656478882
# Best cost: 2285.849742624181
# Best back time: 231.90345170654487
# Number of vehicle: 22
# -------------------------------------------------------
# Test 7/60 | Iteration with this parameters: num_ants = 20 alpha = 2 beta = 1
# Computation time taken: 7.606658220291138
# Best cost: 2228.2202490753007
# Best back time: 237.39295347415407
# Number of vehicle: 21
# -------------------------------------------------------
# Test 8/60 | Iteration with this parameters: num_ants = 20 alpha = 2 beta = 2
# Computation time taken: 7.8819215297698975
# Best cost: 2316.172240904507
# Best back time: 237.39295347415407
# Number of vehicle: 21
# -------------------------------------------------------
# Test 9/60 | Iteration with this parameters: num_ants = 20 alpha = 2 beta = 5
# Computation time taken: 8.392868041992188
# Best cost: 2187.3879916562764
# Best back time: 237.39295347415407
# Number of vehicle: 21
# -------------------------------------------------------
# Test 10/60 | Iteration with this parameters: num_ants = 20 alpha = 5 beta = 1
# Computation time taken: 10.64476752281189
# Best cost: 2272.379741382829
# Best back time: 239.04090400194596
# Number of vehicle: 22
# -------------------------------------------------------
# Test 11/60 | Iteration with this parameters: num_ants = 20 alpha = 5 beta = 2
# Computation time taken: 9.228110551834106
# Best cost: 2265.340422754427
# Best back time: 238.52077291037946
# Number of vehicle: 23
# -------------------------------------------------------
# Test 12/60 | Iteration with this parameters: num_ants = 20 alpha = 5 beta = 5
# Computation time taken: 7.85000467300415
# Best cost: 2324.160036314963
# Best back time: 239.35130762503798
# Number of vehicle: 24
# -------------------------------------------------------
# Test 13/60 | Iteration with this parameters: num_ants = 40 alpha = 0.5 beta = 1
# Computation time taken: 15.448662519454956
# Best cost: 2604.958479408091
# Best back time: 238.83149032587414
# Number of vehicle: 24
# -------------------------------------------------------
# Test 14/60 | Iteration with this parameters: num_ants = 40 alpha = 0.5 beta = 2
# Computation time taken: 15.472642183303833
# Best cost: 2506.5686303252733
# Best back time: 239.36718799662836
# Number of vehicle: 24
# -------------------------------------------------------
# Test 15/60 | Iteration with this parameters: num_ants = 40 alpha = 0.5 beta = 5
# Computation time taken: 15.943420648574829
# Best cost: 2418.3842670381637
# Best back time: 239.0410397789788
# Number of vehicle: 24
# -------------------------------------------------------
# Test 16/60 | Iteration with this parameters: num_ants = 40 alpha = 1 beta = 1
# Computation time taken: 15.47512435913086
# Best cost: 2380.3958991266336
# Best back time: 237.0031501576579
# Number of vehicle: 22
# -------------------------------------------------------
# Test 17/60 | Iteration with this parameters: num_ants = 40 alpha = 1 beta = 2
# Computation time taken: 15.599311351776123
# Best cost: 2259.2116209820488
# Best back time: 238.22503793041454
# Number of vehicle: 21
# -------------------------------------------------------
# Test 18/60 | Iteration with this parameters: num_ants = 40 alpha = 1 beta = 5
# Computation time taken: 18.150979042053223
# Best cost: 2392.297214622362
# Best back time: 237.57348839584006
# Number of vehicle: 22
# -------------------------------------------------------
# Test 19/60 | Iteration with this parameters: num_ants = 40 alpha = 2 beta = 1
# Computation time taken: 18.243058919906616
# Best cost: 2203.797471773516
# Best back time: 237.0031501576579
# Number of vehicle: 22
# -------------------------------------------------------
# Test 20/60 | Iteration with this parameters: num_ants = 40 alpha = 2 beta = 2
# Computation time taken: 18.227482557296753
# Best cost: 2235.0289198953215
# Best back time: 234.04442251822084
# Number of vehicle: 22
# -------------------------------------------------------
# Test 21/60 | Iteration with this parameters: num_ants = 40 alpha = 2 beta = 5
# Computation time taken: 18.163403034210205
# Best cost: 2258.351034930998
# Best back time: 237.39295347415407
# Number of vehicle: 21
# -------------------------------------------------------
# Test 22/60 | Iteration with this parameters: num_ants = 40 alpha = 5 beta = 1
# Computation time taken: 17.25512170791626
# Best cost: 2287.55697747018
# Best back time: 237.0031501576579
# Number of vehicle: 23
# -------------------------------------------------------
# Test 23/60 | Iteration with this parameters: num_ants = 40 alpha = 5 beta = 2
# Computation time taken: 15.310306549072266
# Best cost: 2256.0214873933
# Best back time: 237.0031501576579
# Number of vehicle: 23
# -------------------------------------------------------
# Test 24/60 | Iteration with this parameters: num_ants = 40 alpha = 5 beta = 5
# Computation time taken: 14.894623279571533
# Best cost: 2255.3326876501087
# Best back time: 237.0031501576579
# Number of vehicle: 23
# -------------------------------------------------------
# Test 25/60 | Iteration with this parameters: num_ants = 60 alpha = 0.5 beta = 1
# Computation time taken: 22.602710247039795
# Best cost: 2518.0531855537265
# Best back time: 237.39295347415407
# Number of vehicle: 24
# -------------------------------------------------------
# Test 26/60 | Iteration with this parameters: num_ants = 60 alpha = 0.5 beta = 2
# Computation time taken: 23.165293216705322
# Best cost: 2444.0875726360136
# Best back time: 235.49418824077196
# Number of vehicle: 24
# -------------------------------------------------------
# Test 27/60 | Iteration with this parameters: num_ants = 60 alpha = 0.5 beta = 5
# Computation time taken: 23.239142417907715
# Best cost: 2341.86575158342
# Best back time: 228.19733910065435
# Number of vehicle: 24
# -------------------------------------------------------
# Test 28/60 | Iteration with this parameters: num_ants = 60 alpha = 1 beta = 1
# Computation time taken: 22.325374603271484
# Best cost: 2334.5265057824035
# Best back time: 237.0031501576579
# Number of vehicle: 22
# -------------------------------------------------------
# Test 29/60 | Iteration with this parameters: num_ants = 60 alpha = 1 beta = 2
# Computation time taken: 22.672670125961304
# Best cost: 2315.6631070170406
# Best back time: 235.88618218470003
# Number of vehicle: 22
# -------------------------------------------------------
# Test 30/60 | Iteration with this parameters: num_ants = 60 alpha = 1 beta = 5
# Computation time taken: 22.643271684646606
# Best cost: 2285.4625544614537
# Best back time: 234.04442251822084
# Number of vehicle: 22
# -------------------------------------------------------
# Test 31/60 | Iteration with this parameters: num_ants = 60 alpha = 2 beta = 1
# Computation time taken: 25.93588662147522
# Best cost: 2238.5489687846457
# Best back time: 227.76767170314713
# Number of vehicle: 23
# -------------------------------------------------------
# Test 32/60 | Iteration with this parameters: num_ants = 60 alpha = 2 beta = 2
# Computation time taken: 26.027817487716675
# Best cost: 2132.1223344077225
# Best back time: 237.39295347415407
# Number of vehicle: 21
# -------------------------------------------------------
# Test 33/60 | Iteration with this parameters: num_ants = 60 alpha = 2 beta = 5
# Computation time taken: 23.55007004737854
# Best cost: 2337.4947867497176
# Best back time: 237.39295347415407
# Number of vehicle: 22
# -------------------------------------------------------
# Test 34/60 | Iteration with this parameters: num_ants = 60 alpha = 5 beta = 1
# Computation time taken: 24.65349268913269
# Best cost: 2204.7643932041283
# Best back time: 234.04442251822084
# Number of vehicle: 23
# -------------------------------------------------------
# Test 35/60 | Iteration with this parameters: num_ants = 60 alpha = 5 beta = 2
# Computation time taken: 22.34916639328003
# Best cost: 2314.6250294483107
# Best back time: 237.0031501576579
# Number of vehicle: 23
# -------------------------------------------------------
# Test 36/60 | Iteration with this parameters: num_ants = 60 alpha = 5 beta = 5
# Computation time taken: 22.194881439208984
# Best cost: 2331.2613161103
# Best back time: 237.0031501576579
# Number of vehicle: 23
# -------------------------------------------------------
# Test 37/60 | Iteration with this parameters: num_ants = 80 alpha = 0.5 beta = 1
# Computation time taken: 29.850987195968628
# Best cost: 2517.918314735729
# Best back time: 238.71441222790287
# Number of vehicle: 23
# -------------------------------------------------------
# Test 38/60 | Iteration with this parameters: num_ants = 80 alpha = 0.5 beta = 2
# Computation time taken: 30.525975704193115
# Best cost: 2508.8830155292417
# Best back time: 234.04442251822084
# Number of vehicle: 24
# -------------------------------------------------------
# Test 39/60 | Iteration with this parameters: num_ants = 80 alpha = 0.5 beta = 5
# Computation time taken: 30.50296902656555
# Best cost: 2451.7444695304584
# Best back time: 239.4781612790796
# Number of vehicle: 23
# -------------------------------------------------------
# Test 40/60 | Iteration with this parameters: num_ants = 80 alpha = 1 beta = 1
# Computation time taken: 28.79779577255249
# Best cost: 2397.2557068923234
# Best back time: 236.7558667943452
# Number of vehicle: 21
# -------------------------------------------------------
# Test 41/60 | Iteration with this parameters: num_ants = 80 alpha = 1 beta = 2
# Computation time taken: 29.53092932701111
# Best cost: 2272.4032081689365
# Best back time: 236.68190055660037
# Number of vehicle: 21
# -------------------------------------------------------
# Test 42/60 | Iteration with this parameters: num_ants = 80 alpha = 1 beta = 5
# Computation time taken: 29.248809814453125
# Best cost: 2315.5577667948783
# Best back time: 231.64988762510393
# Number of vehicle: 22
# -------------------------------------------------------
# Test 43/60 | Iteration with this parameters: num_ants = 80 alpha = 2 beta = 1
# Computation time taken: 29.456228494644165
# Best cost: 2178.3503045697507
# Best back time: 239.04090400194596
# Number of vehicle: 22
# -------------------------------------------------------
# Test 44/60 | Iteration with this parameters: num_ants = 80 alpha = 2 beta = 2
# Computation time taken: 29.60984468460083
# Best cost: 2247.7879620693784
# Best back time: 237.39295347415407
# Number of vehicle: 22
# -------------------------------------------------------
# Test 45/60 | Iteration with this parameters: num_ants = 80 alpha = 2 beta = 5
# Computation time taken: 29.370455741882324
# Best cost: 2385.1412673472914
# Best back time: 237.39295347415407
# Number of vehicle: 22
# -------------------------------------------------------
# Test 46/60 | Iteration with this parameters: num_ants = 80 alpha = 5 beta = 1
# Computation time taken: 29.371461391448975
# Best cost: 2215.240235124973
# Best back time: 238.39346890370587
# Number of vehicle: 23
# -------------------------------------------------------
# Test 47/60 | Iteration with this parameters: num_ants = 80 alpha = 5 beta = 2
# Computation time taken: 30.03268313407898
# Best cost: 2291.0805667742497
# Best back time: 237.0031501576579
# Number of vehicle: 24
# -------------------------------------------------------
# Test 48/60 | Iteration with this parameters: num_ants = 80 alpha = 5 beta = 5
# Computation time taken: 29.98381757736206
# Best cost: 2379.656269584433
# Best back time: 239.35130762503798
# Number of vehicle: 24
# -------------------------------------------------------
# Test 49/60 | Iteration with this parameters: num_ants = 100 alpha = 0.5 beta = 1
# Computation time taken: 36.82651901245117
# Best cost: 2537.5965315965877
# Best back time: 238.39446493024684
# Number of vehicle: 24
# -------------------------------------------------------
# Test 50/60 | Iteration with this parameters: num_ants = 100 alpha = 0.5 beta = 2
# Computation time taken: 37.10474967956543
# Best cost: 2383.635702163905
# Best back time: 236.14552105899566
# Number of vehicle: 22
# -------------------------------------------------------
# Test 51/60 | Iteration with this parameters: num_ants = 100 alpha = 0.5 beta = 5
# Computation time taken: 36.983099937438965
# Best cost: 2364.214723665944
# Best back time: 234.04442251822084
# Number of vehicle: 23
# -------------------------------------------------------
# Test 52/60 | Iteration with this parameters: num_ants = 100 alpha = 1 beta = 1
# Computation time taken: 35.90598201751709
# Best cost: 2336.9235782841242
# Best back time: 233.8472094087817
# Number of vehicle: 22
# -------------------------------------------------------
# Test 53/60 | Iteration with this parameters: num_ants = 100 alpha = 1 beta = 2
# Computation time taken: 37.41995692253113
# Best cost: 2280.5034207173812
# Best back time: 237.16029822724943
# Number of vehicle: 22
# -------------------------------------------------------
# Test 54/60 | Iteration with this parameters: num_ants = 100 alpha = 1 beta = 5
# Computation time taken: 38.826374530792236
# Best cost: 2359.1361021889206
# Best back time: 239.0410397789788
# Number of vehicle: 23
# -------------------------------------------------------
# Test 55/60 | Iteration with this parameters: num_ants = 100 alpha = 2 beta = 1
# Computation time taken: 37.697190046310425
# Best cost: 2259.691191627877
# Best back time: 230.58521005519424
# Number of vehicle: 21
# -------------------------------------------------------
# Test 56/60 | Iteration with this parameters: num_ants = 100 alpha = 2 beta = 2
# Computation time taken: 37.48373627662659
# Best cost: 2192.5316690668988
# Best back time: 237.39295347415407
# Number of vehicle: 21
# -------------------------------------------------------
# Test 57/60 | Iteration with this parameters: num_ants = 100 alpha = 2 beta = 5
# Computation time taken: 38.39060950279236
# Best cost: 2205.928799126068
# Best back time: 237.39295347415407
# Number of vehicle: 22
# -------------------------------------------------------
# Test 58/60 | Iteration with this parameters: num_ants = 100 alpha = 5 beta = 1
# Computation time taken: 36.75212478637695
# Best cost: 2280.9798367675467
# Best back time: 236.5709236709843
# Number of vehicle: 23
# -------------------------------------------------------
# Test 59/60 | Iteration with this parameters: num_ants = 100 alpha = 5 beta = 2
# Computation time taken: 37.62998604774475
# Best cost: 2183.1635447798217
# Best back time: 234.04442251822084
# Number of vehicle: 24
# -------------------------------------------------------
# Test 60/60 | Iteration with this parameters: num_ants = 100 alpha = 5 beta = 5
# Computation time taken: 37.40549159049988
# Best cost: 2299.20038391701
# Best back time: 238.52077291037946
# Number of vehicle: 23
# Minimum number of vehicle: 21

# %%
print(best_length_table)

plt.figure(figsize=(12, 8)) 
plt.plot(best_length_table, marker='o', color='blue', label="Best Cost")
plt.xlabel("Iteration", fontsize=14)
plt.ylabel("Best Cost", fontsize=14)
plt.title("Evolution of the Cost as a Function of the Iteration for RC instances", fontsize=16)
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [11588.57435706217, 4678.065604911433, 2529.768152602206, 2529.768152602206, 2529.768152602206, 2529.768152602206, 2529.768152602206, 2465.876672336093, 2496.1353655697603, 2496.1353655697603, 2334.390386722578, 2334.390386722578, 2334.390386722578, 2334.390386722578, 2334.390386722578, 2334.390386722578, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293, 2448.156068766293]
