# %%
from scipy.spatial import distance_matrix
import numpy as np
import matplotlib.pyplot as plt
import random
import math

# %%
dataset_name = 'c101'
file_path = '../2nd deliverable/solomon-100/'+dataset_name+'.txt'

# Initialize lists to store vehicle and customer data
vehicle_data = []
customer_data = []

# Read data line by line
with open(file_path, 'r') as file:
    lines = file.readlines()
    
    # Parse vehicle data
    vehicle_info_start = lines.index('VEHICLE\n') + 2
    vehicle_info_end = lines.index('CUSTOMER\n')
    vehicle_line = lines[vehicle_info_start].strip().split()
    
    # Store vehicle data as a dictionary in a list
    vehicle_data.append({
        'NUMBER': int(vehicle_line[0]),
        'CAPACITY': int(vehicle_line[1])
    })
    
    # Parse customer data
    customer_info_start = vehicle_info_end + 2
    for line in lines[customer_info_start:]:
        if line.strip():  # Skip any empty lines
            parts = line.strip().split()
            customer_data.append({
                'CUST_NO': int(parts[0]),
                'XCOORD': int(parts[1]),
                'YCOORD': int(parts[2]),
                'DEMAND': int(parts[3]),
                'READY_TIME': int(parts[4]),
                'DUE_DATE': int(parts[5]),
                'SERVICE_TIME': int(parts[6])
            })

# Display the parsed data
print("Vehicle Data:")
print(vehicle_data)
print("\nCustomer Data:")
for customer in customer_data:  # Show first 5 customers for brevity
    print(customer)
# Out:
# Vehicle Data:
# [{'NUMBER': 25, 'CAPACITY': 200}]
#
# Customer Data:
# {'CUST_NO': 0, 'XCOORD': 40, 'YCOORD': 50, 'DEMAND': 0, 'READY_TIME': 0, 'DUE_DATE': 1236, 'SERVICE_TIME': 0}
# {'CUST_NO': 1, 'XCOORD': 45, 'YCOORD': 68, 'DEMAND': 10, 'READY_TIME': 912, 'DUE_DATE': 967, 'SERVICE_TIME': 90}
# {'CUST_NO': 2, 'XCOORD': 45, 'YCOORD': 70, 'DEMAND': 30, 'READY_TIME': 825, 'DUE_DATE': 870, 'SERVICE_TIME': 90}
# {'CUST_NO': 3, 'XCOORD': 42, 'YCOORD': 66, 'DEMAND': 10, 'READY_TIME': 65, 'DUE_DATE': 146, 'SERVICE_TIME': 90}
# {'CUST_NO': 4, 'XCOORD': 42, 'YCOORD': 68, 'DEMAND': 10, 'READY_TIME': 727, 'DUE_DATE': 782, 'SERVICE_TIME': 90}
# {'CUST_NO': 5, 'XCOORD': 42, 'YCOORD': 65, 'DEMAND': 10, 'READY_TIME': 15, 'DUE_DATE': 67, 'SERVICE_TIME': 90}
# {'CUST_NO': 6, 'XCOORD': 40, 'YCOORD': 69, 'DEMAND': 20, 'READY_TIME': 621, 'DUE_DATE': 702, 'SERVICE_TIME': 90}
# {'CUST_NO': 7, 'XCOORD': 40, 'YCOORD': 66, 'DEMAND': 20, 'READY_TIME': 170, 'DUE_DATE': 225, 'SERVICE_TIME': 90}
# {'CUST_NO': 8, 'XCOORD': 38, 'YCOORD': 68, 'DEMAND': 20, 'READY_TIME': 255, 'DUE_DATE': 324, 'SERVICE_TIME': 90}
# {'CUST_NO': 9, 'XCOORD': 38, 'YCOORD': 70, 'DEMAND': 10, 'READY_TIME': 534, 'DUE_DATE': 605, 'SERVICE_TIME': 90}
# {'CUST_NO': 10, 'XCOORD': 35, 'YCOORD': 66, 'DEMAND': 10, 'READY_TIME': 357, 'DUE_DATE': 410, 'SERVICE_TIME': 90}
# {'CUST_NO': 11, 'XCOORD': 35, 'YCOORD': 69, 'DEMAND': 10, 'READY_TIME': 448, 'DUE_DATE': 505, 'SERVICE_TIME': 90}
# {'CUST_NO': 12, 'XCOORD': 25, 'YCOORD': 85, 'DEMAND': 20, 'READY_TIME': 652, 'DUE_DATE': 721, 'SERVICE_TIME': 90}
# {'CUST_NO': 13, 'XCOORD': 22, 'YCOORD': 75, 'DEMAND': 30, 'READY_TIME': 30, 'DUE_DATE': 92, 'SERVICE_TIME': 90}
# {'CUST_NO': 14, 'XCOORD': 22, 'YCOORD': 85, 'DEMAND': 10, 'READY_TIME': 567, 'DUE_DATE': 620, 'SERVICE_TIME': 90}
# {'CUST_NO': 15, 'XCOORD': 20, 'YCOORD': 80, 'DEMAND': 40, 'READY_TIME': 384, 'DUE_DATE': 429, 'SERVICE_TIME': 90}
# {'CUST_NO': 16, 'XCOORD': 20, 'YCOORD': 85, 'DEMAND': 40, 'READY_TIME': 475, 'DUE_DATE': 528, 'SERVICE_TIME': 90}
# {'CUST_NO': 17, 'XCOORD': 18, 'YCOORD': 75, 'DEMAND': 20, 'READY_TIME': 99, 'DUE_DATE': 148, 'SERVICE_TIME': 90}
# {'CUST_NO': 18, 'XCOORD': 15, 'YCOORD': 75, 'DEMAND': 20, 'READY_TIME': 179, 'DUE_DATE': 254, 'SERVICE_TIME': 90}
# {'CUST_NO': 19, 'XCOORD': 15, 'YCOORD': 80, 'DEMAND': 10, 'READY_TIME': 278, 'DUE_DATE': 345, 'SERVICE_TIME': 90}
# {'CUST_NO': 20, 'XCOORD': 30, 'YCOORD': 50, 'DEMAND': 10, 'READY_TIME': 10, 'DUE_DATE': 73, 'SERVICE_TIME': 90}
# {'CUST_NO': 21, 'XCOORD': 30, 'YCOORD': 52, 'DEMAND': 20, 'READY_TIME': 914, 'DUE_DATE': 965, 'SERVICE_TIME': 90}
# {'CUST_NO': 22, 'XCOORD': 28, 'YCOORD': 52, 'DEMAND': 20, 'READY_TIME': 812, 'DUE_DATE': 883, 'SERVICE_TIME': 90}
# {'CUST_NO': 23, 'XCOORD': 28, 'YCOORD': 55, 'DEMAND': 10, 'READY_TIME': 732, 'DUE_DATE': 777, 'SERVICE_TIME': 90}
# {'CUST_NO': 24, 'XCOORD': 25, 'YCOORD': 50, 'DEMAND': 10, 'READY_TIME': 65, 'DUE_DATE': 144, 'SERVICE_TIME': 90}
# {'CUST_NO': 25, 'XCOORD': 25, 'YCOORD': 52, 'DEMAND': 40, 'READY_TIME': 169, 'DUE_DATE': 224, 'SERVICE_TIME': 90}
# {'CUST_NO': 26, 'XCOORD': 25, 'YCOORD': 55, 'DEMAND': 10, 'READY_TIME': 622, 'DUE_DATE': 701, 'SERVICE_TIME': 90}
# {'CUST_NO': 27, 'XCOORD': 23, 'YCOORD': 52, 'DEMAND': 10, 'READY_TIME': 261, 'DUE_DATE': 316, 'SERVICE_TIME': 90}
# {'CUST_NO': 28, 'XCOORD': 23, 'YCOORD': 55, 'DEMAND': 20, 'READY_TIME': 546, 'DUE_DATE': 593, 'SERVICE_TIME': 90}
# {'CUST_NO': 29, 'XCOORD': 20, 'YCOORD': 50, 'DEMAND': 10, 'READY_TIME': 358, 'DUE_DATE': 405, 'SERVICE_TIME': 90}
# {'CUST_NO': 30, 'XCOORD': 20, 'YCOORD': 55, 'DEMAND': 10, 'READY_TIME': 449, 'DUE_DATE': 504, 'SERVICE_TIME': 90}
# {'CUST_NO': 31, 'XCOORD': 10, 'YCOORD': 35, 'DEMAND': 20, 'READY_TIME': 200, 'DUE_DATE': 237, 'SERVICE_TIME': 90}
# {'CUST_NO': 32, 'XCOORD': 10, 'YCOORD': 40, 'DEMAND': 30, 'READY_TIME': 31, 'DUE_DATE': 100, 'SERVICE_TIME': 90}
# {'CUST_NO': 33, 'XCOORD': 8, 'YCOORD': 40, 'DEMAND': 40, 'READY_TIME': 87, 'DUE_DATE': 158, 'SERVICE_TIME': 90}
# {'CUST_NO': 34, 'XCOORD': 8, 'YCOORD': 45, 'DEMAND': 20, 'READY_TIME': 751, 'DUE_DATE': 816, 'SERVICE_TIME': 90}
# {'CUST_NO': 35, 'XCOORD': 5, 'YCOORD': 35, 'DEMAND': 10, 'READY_TIME': 283, 'DUE_DATE': 344, 'SERVICE_TIME': 90}
# {'CUST_NO': 36, 'XCOORD': 5, 'YCOORD': 45, 'DEMAND': 10, 'READY_TIME': 665, 'DUE_DATE': 716, 'SERVICE_TIME': 90}
# {'CUST_NO': 37, 'XCOORD': 2, 'YCOORD': 40, 'DEMAND': 20, 'READY_TIME': 383, 'DUE_DATE': 434, 'SERVICE_TIME': 90}
# {'CUST_NO': 38, 'XCOORD': 0, 'YCOORD': 40, 'DEMAND': 30, 'READY_TIME': 479, 'DUE_DATE': 522, 'SERVICE_TIME': 90}
# {'CUST_NO': 39, 'XCOORD': 0, 'YCOORD': 45, 'DEMAND': 20, 'READY_TIME': 567, 'DUE_DATE': 624, 'SERVICE_TIME': 90}
# {'CUST_NO': 40, 'XCOORD': 35, 'YCOORD': 30, 'DEMAND': 10, 'READY_TIME': 264, 'DUE_DATE': 321, 'SERVICE_TIME': 90}
# {'CUST_NO': 41, 'XCOORD': 35, 'YCOORD': 32, 'DEMAND': 10, 'READY_TIME': 166, 'DUE_DATE': 235, 'SERVICE_TIME': 90}
# {'CUST_NO': 42, 'XCOORD': 33, 'YCOORD': 32, 'DEMAND': 20, 'READY_TIME': 68, 'DUE_DATE': 149, 'SERVICE_TIME': 90}
# {'CUST_NO': 43, 'XCOORD': 33, 'YCOORD': 35, 'DEMAND': 10, 'READY_TIME': 16, 'DUE_DATE': 80, 'SERVICE_TIME': 90}
# {'CUST_NO': 44, 'XCOORD': 32, 'YCOORD': 30, 'DEMAND': 10, 'READY_TIME': 359, 'DUE_DATE': 412, 'SERVICE_TIME': 90}
# {'CUST_NO': 45, 'XCOORD': 30, 'YCOORD': 30, 'DEMAND': 10, 'READY_TIME': 541, 'DUE_DATE': 600, 'SERVICE_TIME': 90}
# {'CUST_NO': 46, 'XCOORD': 30, 'YCOORD': 32, 'DEMAND': 30, 'READY_TIME': 448, 'DUE_DATE': 509, 'SERVICE_TIME': 90}
# {'CUST_NO': 47, 'XCOORD': 30, 'YCOORD': 35, 'DEMAND': 10, 'READY_TIME': 1054, 'DUE_DATE': 1127, 'SERVICE_TIME': 90}
# {'CUST_NO': 48, 'XCOORD': 28, 'YCOORD': 30, 'DEMAND': 10, 'READY_TIME': 632, 'DUE_DATE': 693, 'SERVICE_TIME': 90}
# {'CUST_NO': 49, 'XCOORD': 28, 'YCOORD': 35, 'DEMAND': 10, 'READY_TIME': 1001, 'DUE_DATE': 1066, 'SERVICE_TIME': 90}
# {'CUST_NO': 50, 'XCOORD': 26, 'YCOORD': 32, 'DEMAND': 10, 'READY_TIME': 815, 'DUE_DATE': 880, 'SERVICE_TIME': 90}
# {'CUST_NO': 51, 'XCOORD': 25, 'YCOORD': 30, 'DEMAND': 10, 'READY_TIME': 725, 'DUE_DATE': 786, 'SERVICE_TIME': 90}
# {'CUST_NO': 52, 'XCOORD': 25, 'YCOORD': 35, 'DEMAND': 10, 'READY_TIME': 912, 'DUE_DATE': 969, 'SERVICE_TIME': 90}
# {'CUST_NO': 53, 'XCOORD': 44, 'YCOORD': 5, 'DEMAND': 20, 'READY_TIME': 286, 'DUE_DATE': 347, 'SERVICE_TIME': 90}
# {'CUST_NO': 54, 'XCOORD': 42, 'YCOORD': 10, 'DEMAND': 40, 'READY_TIME': 186, 'DUE_DATE': 257, 'SERVICE_TIME': 90}
# {'CUST_NO': 55, 'XCOORD': 42, 'YCOORD': 15, 'DEMAND': 10, 'READY_TIME': 95, 'DUE_DATE': 158, 'SERVICE_TIME': 90}
# {'CUST_NO': 56, 'XCOORD': 40, 'YCOORD': 5, 'DEMAND': 30, 'READY_TIME': 385, 'DUE_DATE': 436, 'SERVICE_TIME': 90}
# {'CUST_NO': 57, 'XCOORD': 40, 'YCOORD': 15, 'DEMAND': 40, 'READY_TIME': 35, 'DUE_DATE': 87, 'SERVICE_TIME': 90}
# {'CUST_NO': 58, 'XCOORD': 38, 'YCOORD': 5, 'DEMAND': 30, 'READY_TIME': 471, 'DUE_DATE': 534, 'SERVICE_TIME': 90}
# {'CUST_NO': 59, 'XCOORD': 38, 'YCOORD': 15, 'DEMAND': 10, 'READY_TIME': 651, 'DUE_DATE': 740, 'SERVICE_TIME': 90}
# {'CUST_NO': 60, 'XCOORD': 35, 'YCOORD': 5, 'DEMAND': 20, 'READY_TIME': 562, 'DUE_DATE': 629, 'SERVICE_TIME': 90}
# {'CUST_NO': 61, 'XCOORD': 50, 'YCOORD': 30, 'DEMAND': 10, 'READY_TIME': 531, 'DUE_DATE': 610, 'SERVICE_TIME': 90}
# {'CUST_NO': 62, 'XCOORD': 50, 'YCOORD': 35, 'DEMAND': 20, 'READY_TIME': 262, 'DUE_DATE': 317, 'SERVICE_TIME': 90}
# {'CUST_NO': 63, 'XCOORD': 50, 'YCOORD': 40, 'DEMAND': 50, 'READY_TIME': 171, 'DUE_DATE': 218, 'SERVICE_TIME': 90}
# {'CUST_NO': 64, 'XCOORD': 48, 'YCOORD': 30, 'DEMAND': 10, 'READY_TIME': 632, 'DUE_DATE': 693, 'SERVICE_TIME': 90}
# {'CUST_NO': 65, 'XCOORD': 48, 'YCOORD': 40, 'DEMAND': 10, 'READY_TIME': 76, 'DUE_DATE': 129, 'SERVICE_TIME': 90}
# {'CUST_NO': 66, 'XCOORD': 47, 'YCOORD': 35, 'DEMAND': 10, 'READY_TIME': 826, 'DUE_DATE': 875, 'SERVICE_TIME': 90}
# {'CUST_NO': 67, 'XCOORD': 47, 'YCOORD': 40, 'DEMAND': 10, 'READY_TIME': 12, 'DUE_DATE': 77, 'SERVICE_TIME': 90}
# {'CUST_NO': 68, 'XCOORD': 45, 'YCOORD': 30, 'DEMAND': 10, 'READY_TIME': 734, 'DUE_DATE': 777, 'SERVICE_TIME': 90}
# {'CUST_NO': 69, 'XCOORD': 45, 'YCOORD': 35, 'DEMAND': 10, 'READY_TIME': 916, 'DUE_DATE': 969, 'SERVICE_TIME': 90}
# {'CUST_NO': 70, 'XCOORD': 95, 'YCOORD': 30, 'DEMAND': 30, 'READY_TIME': 387, 'DUE_DATE': 456, 'SERVICE_TIME': 90}
# {'CUST_NO': 71, 'XCOORD': 95, 'YCOORD': 35, 'DEMAND': 20, 'READY_TIME': 293, 'DUE_DATE': 360, 'SERVICE_TIME': 90}
# {'CUST_NO': 72, 'XCOORD': 53, 'YCOORD': 30, 'DEMAND': 10, 'READY_TIME': 450, 'DUE_DATE': 505, 'SERVICE_TIME': 90}
# {'CUST_NO': 73, 'XCOORD': 92, 'YCOORD': 30, 'DEMAND': 10, 'READY_TIME': 478, 'DUE_DATE': 551, 'SERVICE_TIME': 90}
# {'CUST_NO': 74, 'XCOORD': 53, 'YCOORD': 35, 'DEMAND': 50, 'READY_TIME': 353, 'DUE_DATE': 412, 'SERVICE_TIME': 90}
# {'CUST_NO': 75, 'XCOORD': 45, 'YCOORD': 65, 'DEMAND': 20, 'READY_TIME': 997, 'DUE_DATE': 1068, 'SERVICE_TIME': 90}
# {'CUST_NO': 76, 'XCOORD': 90, 'YCOORD': 35, 'DEMAND': 10, 'READY_TIME': 203, 'DUE_DATE': 260, 'SERVICE_TIME': 90}
# {'CUST_NO': 77, 'XCOORD': 88, 'YCOORD': 30, 'DEMAND': 10, 'READY_TIME': 574, 'DUE_DATE': 643, 'SERVICE_TIME': 90}
# {'CUST_NO': 78, 'XCOORD': 88, 'YCOORD': 35, 'DEMAND': 20, 'READY_TIME': 109, 'DUE_DATE': 170, 'SERVICE_TIME': 90}
# {'CUST_NO': 79, 'XCOORD': 87, 'YCOORD': 30, 'DEMAND': 10, 'READY_TIME': 668, 'DUE_DATE': 731, 'SERVICE_TIME': 90}
# {'CUST_NO': 80, 'XCOORD': 85, 'YCOORD': 25, 'DEMAND': 10, 'READY_TIME': 769, 'DUE_DATE': 820, 'SERVICE_TIME': 90}
# {'CUST_NO': 81, 'XCOORD': 85, 'YCOORD': 35, 'DEMAND': 30, 'READY_TIME': 47, 'DUE_DATE': 124, 'SERVICE_TIME': 90}
# {'CUST_NO': 82, 'XCOORD': 75, 'YCOORD': 55, 'DEMAND': 20, 'READY_TIME': 369, 'DUE_DATE': 420, 'SERVICE_TIME': 90}
# {'CUST_NO': 83, 'XCOORD': 72, 'YCOORD': 55, 'DEMAND': 10, 'READY_TIME': 265, 'DUE_DATE': 338, 'SERVICE_TIME': 90}
# {'CUST_NO': 84, 'XCOORD': 70, 'YCOORD': 58, 'DEMAND': 20, 'READY_TIME': 458, 'DUE_DATE': 523, 'SERVICE_TIME': 90}
# {'CUST_NO': 85, 'XCOORD': 68, 'YCOORD': 60, 'DEMAND': 30, 'READY_TIME': 555, 'DUE_DATE': 612, 'SERVICE_TIME': 90}
# {'CUST_NO': 86, 'XCOORD': 66, 'YCOORD': 55, 'DEMAND': 10, 'READY_TIME': 173, 'DUE_DATE': 238, 'SERVICE_TIME': 90}
# {'CUST_NO': 87, 'XCOORD': 65, 'YCOORD': 55, 'DEMAND': 20, 'READY_TIME': 85, 'DUE_DATE': 144, 'SERVICE_TIME': 90}
# {'CUST_NO': 88, 'XCOORD': 65, 'YCOORD': 60, 'DEMAND': 30, 'READY_TIME': 645, 'DUE_DATE': 708, 'SERVICE_TIME': 90}
# {'CUST_NO': 89, 'XCOORD': 63, 'YCOORD': 58, 'DEMAND': 10, 'READY_TIME': 737, 'DUE_DATE': 802, 'SERVICE_TIME': 90}
# {'CUST_NO': 90, 'XCOORD': 60, 'YCOORD': 55, 'DEMAND': 10, 'READY_TIME': 20, 'DUE_DATE': 84, 'SERVICE_TIME': 90}
# {'CUST_NO': 91, 'XCOORD': 60, 'YCOORD': 60, 'DEMAND': 10, 'READY_TIME': 836, 'DUE_DATE': 889, 'SERVICE_TIME': 90}
# {'CUST_NO': 92, 'XCOORD': 67, 'YCOORD': 85, 'DEMAND': 20, 'READY_TIME': 368, 'DUE_DATE': 441, 'SERVICE_TIME': 90}
# {'CUST_NO': 93, 'XCOORD': 65, 'YCOORD': 85, 'DEMAND': 40, 'READY_TIME': 475, 'DUE_DATE': 518, 'SERVICE_TIME': 90}
# {'CUST_NO': 94, 'XCOORD': 65, 'YCOORD': 82, 'DEMAND': 10, 'READY_TIME': 285, 'DUE_DATE': 336, 'SERVICE_TIME': 90}
# {'CUST_NO': 95, 'XCOORD': 62, 'YCOORD': 80, 'DEMAND': 30, 'READY_TIME': 196, 'DUE_DATE': 239, 'SERVICE_TIME': 90}
# {'CUST_NO': 96, 'XCOORD': 60, 'YCOORD': 80, 'DEMAND': 10, 'READY_TIME': 95, 'DUE_DATE': 156, 'SERVICE_TIME': 90}
# {'CUST_NO': 97, 'XCOORD': 60, 'YCOORD': 85, 'DEMAND': 30, 'READY_TIME': 561, 'DUE_DATE': 622, 'SERVICE_TIME': 90}
# {'CUST_NO': 98, 'XCOORD': 58, 'YCOORD': 75, 'DEMAND': 20, 'READY_TIME': 30, 'DUE_DATE': 84, 'SERVICE_TIME': 90}
# {'CUST_NO': 99, 'XCOORD': 55, 'YCOORD': 80, 'DEMAND': 10, 'READY_TIME': 743, 'DUE_DATE': 820, 'SERVICE_TIME': 90}
# {'CUST_NO': 100, 'XCOORD': 55, 'YCOORD': 85, 'DEMAND': 20, 'READY_TIME': 647, 'DUE_DATE': 726, 'SERVICE_TIME': 90}

# %%
class Node:
    def __init__(self, id, x, y, demand, ready_time, due_date, service_time):
        self.id = id
        self.is_depot = (id == 0)
        self.x = x
        self.y = y
        self.demand = demand
        self.ready_time = ready_time
        self.due_date = due_date
        self.service_time = 10
        self.visited = False

# %%
class Graph:
    def __init__(self, vehicle_data, customer_data):
        self.vehicle_data = vehicle_data
        self.customer_data = customer_data
        self.nodes = []
        self.vehicle_capacity = vehicle_data[0]['CAPACITY']
        self.num_vehicles = vehicle_data[0]['NUMBER']
        self.setup_nodes()
        self.setup_distance_matrix()
        self.setup_heuristic_matrix()
        self.initialize_pheromone_matrix()
        
    def setup_heuristic_matrix(self):
        self.heuristic_matrix = 1 / self.distance_matrix
        
    def setup_nodes(self):
        for customer in self.customer_data:
            node = Node(customer['CUST_NO'], customer['XCOORD'], customer['YCOORD'], customer['DEMAND'],
                        customer['READY_TIME'], customer['DUE_DATE'], customer['SERVICE_TIME'])
            self.nodes.append(node)
    
    def setup_distance_matrix(self):
        coords = [(node.x, node.y) for node in self.nodes]
        self.distance_matrix = distance_matrix(coords, coords)
        
    def initialize_pheromone_matrix(self):
        n = len(self.nodes)
        self.pheromone_matrix = [[1.0 for _ in range(n)] for _ in range(n)]
    
    def route_distance(self, route):
        distance = 0
        for i in range(len(route) - 1):
            distance += self.distance_matrix[route[i]][route[i + 1]]
        return distance
    
    def update_pheromones(self, ant_solutions, evaporation_rate=0.5):
        # Evaporate pheromones
        for i in range(len(self.pheromone_matrix)):
            for j in range(len(self.pheromone_matrix)):
                self.pheromone_matrix[i][j] = max(self.pheromone_matrix[i][j] * (1 - evaporation_rate), 1e-5)

        
        # Deposit pheromones based on ant solutions
        total_distance = sum(self.route_distance(route) for solution in ant_solutions for route in solution)
        for route in ant_solutions:
            for k in range(len(route) - 1):
                i, j = route[k], route[k + 1]
                self.pheromone_matrix[i][j] += (1 / self.route_distance(route)) / total_distance

# %%
def aco_vrp(G, num_ants, num_iterations, alpha=1.5, beta=2.5, evaporation_rate=0.5, q=100):
    """
    Ant Colony Optimization for Vehicle Routing Problem with Time Windows.
    """
    adj_matrix = G.distance_matrix
    capacity_max = G.vehicle_capacity
    num_points = adj_matrix.shape[0]
    ph_matrix = G.pheromone_matrix  # Initial pheromone matrix
    best_solution = None
    best_cost = float('inf')

    def calculate_probabilities(current_node, unvisited, current_time, current_capacity):
        """
        Calculate probabilities of moving to the next node considering time windows and capacity constraints.
        """
        attractiveness = []
        for neighbor in unvisited:
            travel_time = G.distance_matrix[current_node][neighbor]
            arrival_time = current_time + travel_time
            if (G.nodes[neighbor].demand + current_capacity <= capacity_max
                    and arrival_time <= G.nodes[neighbor].due_date):
                tau = ph_matrix[current_node][neighbor] ** alpha
                eta = (1.0 / G.distance_matrix[current_node][neighbor]) ** beta
                attractiveness.append(tau * eta)
            else:
                attractiveness.append(0)
        total = sum(attractiveness)
        if total == 0:  # Avoid division by zero
            return np.zeros(len(unvisited))
        return np.array(attractiveness) / total

    def construct_solution():
        routes = []
        for node in G.nodes:
            node.visited = False

        while any(not node.visited for node in G.nodes[1:]):  # Exclude the depot
            current_node = 0  # Start at depot
            current_time = G.nodes[current_node].ready_time
            current_capacity = 0
            route = [current_node]

            while True:
                unvisited = [i for i in range(1, len(G.nodes)) if not G.nodes[i].visited]
                if not unvisited:
                    print(current_time)
                    break

                probabilities = calculate_probabilities(current_node, unvisited, current_time, current_capacity)
                if not probabilities.any():  # No valid moves
                    break

                next_node = random.choices(unvisited, weights=probabilities)[0]
                travel_time = G.distance_matrix[current_node][next_node]
                arrival_time = current_time + travel_time

                # Validate constraints
                if (current_capacity + G.nodes[next_node].demand <= capacity_max
                        and arrival_time <= G.nodes[next_node].due_date):
                    current_time = max(arrival_time, G.nodes[next_node].ready_time) + G.nodes[next_node].service_time
                    current_capacity += G.nodes[next_node].demand
                    route.append(next_node)
                    G.nodes[next_node].visited = True
                    current_node = next_node
                else:
                    break  # No valid moves; end route

            # Return to depot
            route.append(0)
            routes.append(route)


        return routes



    def calculate_total_distance(route):
        """
        Calculate the total distance of a given route using the distance matrix.
        """
        total_distance = 0
        for i in range(len(route) - 1):
            current_node = route[i]
            next_node = route[i + 1]
            total_distance += G.distance_matrix[current_node][next_node]
        return total_distance

    
    def calculate_cost(routes):
        total_cost = 0
        num_vehicles = len(routes)
        if num_vehicles > G.num_vehicles:  # Penalty for exceeding vehicle limits
            total_cost += 10000 * (num_vehicles - G.num_vehicles)
        for route in routes:
            total_cost += calculate_total_distance(route)
        return total_cost



    def update_pheromones(all_solutions, ph_matrix, evaporation_rate=0.5):
        # Evaporate pheromones
        for i in range(len(ph_matrix)):
            for j in range(len(ph_matrix[i])):
                ph_matrix[i][j] *= (1 - evaporation_rate)
                ph_matrix[i][j] = max(ph_matrix[i][j], 1e-5)  # Prevent near-zero pheromones

        # Deposit pheromones for each solution
        for solution in all_solutions:
            routes = solution  # Each solution is a list of routes
            for route in routes:
                route_distance = calculate_total_distance(route)
                pheromone_deposit = q / max(route_distance, 1e-5)  # Prevent division by zero
                for i in range(len(route) - 1):
                    a, b = route[i], route[i + 1]
                    ph_matrix[a][b] += pheromone_deposit
                    ph_matrix[b][a] = ph_matrix[a][b]  # Ensure symmetry



    # Main ACO loop
    for iteration in range(num_iterations):
        all_solutions = []
        all_costs = []

        for _ in range(num_ants):
            solution = construct_solution()
            cost = calculate_cost(solution)
            all_solutions.append(solution)
            all_costs.append(cost)

            if cost < best_cost:
                best_cost = cost
                best_solution = solution

        # Update pheromones with all solutions
        update_pheromones(all_solutions, G.pheromone_matrix)
        print(f"Iteration {iteration + 1}: Best cost = {best_cost}")



    return best_solution, best_cost

# %%
import matplotlib.pyplot as plt

def plot_solution(graph, solution):
    """
    Plot the solution of the VRP problem.
    Args:
        graph: Graph object containing node information.
        solution: List of routes (e.g., [[0, 1, 3, 0], [0, 2, 4, 0], ...]).
    """
    # Extract node coordinates
    x_coords = [node.x for node in graph.nodes]
    y_coords = [node.y for node in graph.nodes]

    # Create the plot
    plt.figure(figsize=(10, 8))

    # Plot all nodes
    plt.scatter(x_coords, y_coords, color="blue", label="Customers", zorder=5)
    
    # Highlight the depot (node 0)
    plt.scatter(x_coords[0], y_coords[0], color="red", label="Depot", zorder=5, s=100)

    # Annotate each node with its ID
    for node in graph.nodes:
        plt.text(node.x, node.y, f"{node.id}", fontsize=8, ha="right", va="bottom")

    # Plot each route
    for route in solution:
        route_coords_x = [x_coords[i] for i in route]
        route_coords_y = [y_coords[i] for i in route]
        plt.plot(route_coords_x, route_coords_y, label=f"Route {solution.index(route) + 1}")

    # Customize the plot
    plt.title("Vehicle Routing Problem Solution")
    plt.xlabel("X Coordinate")
    plt.ylabel("Y Coordinate")
    plt.legend()
    plt.grid()
    plt.show()

# %%
G = Graph(vehicle_data, customer_data)

# Run ACO
best_solution_data, best_cost = aco_vrp(
    G,
    num_ants=15, num_iterations=200, alpha=1.5, beta=2.5, evaporation_rate=0.5, q=100
)

print(best_solution_data,best_cost)

# Call the plotting function with the best solution
plot_solution(G, best_solution_data)
# Out:
# 90.67402498121706
# 45.0
# 86.80584360149872
# 109
# 97
# 132.0
# 40.80584360149872
# 57.43416490252569
# 45.0
# 40.80584360149872
# 40.80584360149872
# 189
# 86.80584360149872
# 109
# 119
# Iteration 1: Best cost = 2460.2950468472322
# 132.0
# 105
# 206
# C:\Users\Axel\AppData\Local\Temp\ipykernel_12876\1037172100.py:14: RuntimeWarning: divide by zero encountered in divide
#   self.heuristic_matrix = 1 / self.distance_matrix
# 41.622776601683796
# 119
# 196
# 275
# 72.63114931525254
# 275
# 288
# 45.0
# 288
# 40.80584360149872
# 57.43416490252569
# 176
# Iteration 2: Best cost = 1810.8991907122497
# 132.0
# 119
# 180
# 57.43416490252569
# 97
# 95
# 288
# 105
# 176
# 213
# 146.2842712474619
# 213
# 119
# 57.43416490252569
# 119
# Iteration 3: Best cost = 1504.306080967317
# 40.80584360149872
# 132.0
# 213
# 109
# 183
# 132.0
# 94.05124837953326
# 213
# 213
# 57.43416490252569
# 132.0
# 303
# 176
# 40.80584360149872
# 379
# Iteration 4: Best cost = 1482.5714634337628
# 213
# 30.615528128088304
# 119
# 206
# 45.0
# 119
# 105
# 30.615528128088304
# 57.43416490252569
# 57.43416490252569
# 368
# 119
# 97
# 210
# 133.2842712474619
# Iteration 5: Best cost = 1482.5714634337628
# 57.43416490252569
# 189
# 109.0
# 119
# 105
# 105
# 210
# 40.80584360149872
# 293
# 189
# 57.43416490252569
# 57.43416490252569
# 119
# 213
# 57.43416490252569
# Iteration 6: Best cost = 1482.5714634337628
# 119
# 45.0
# 105
# 458
# 378
# 119
# 40.80584360149872
# 303
# 97
# 105
# 397
# 109.0
# 109
# 104.24428900898053
# 393
# Iteration 7: Best cost = 1332.3152684015936
# 105
# 189
# 206
# 303
# 57.43416490252569
# 97
# 57.43416490252569
# 119
# 275
# 105
# 119
# 295
# 132.0
# 45.0
# 303
# Iteration 8: Best cost = 1332.3152684015936
# 303
# 206
# 57.43416490252569
# 303
# 119
# 213
# 394
# 57.43416490252569
# 395
# 196
# 57.43416490252569
# 189
# 41.622776601683796
# 119
# 213
# Iteration 9: Best cost = 1332.3152684015936
# 395
# 303
# 378
# 393
# 45.0
# 303
# 213
# 395
# 109
# 213
# 394
# 57.43416490252569
# 105
# 303
# 45.0
# Iteration 10: Best cost = 1332.3152684015936
# 213
# 368
# 485
# 40.80584360149872
# 125.43157642872126
# 213
# 41.622776601683796
# 303
# 295
# 40.80584360149872
# 296
# 189
# 210
# 57.43416490252569
# 213
# Iteration 11: Best cost = 1332.3152684015936
# 206
# 189
# 210
# 57.43416490252569
# 393
# 97
# 210
# 119
# 210
# 95
# 303
# 97
# 119
# 295
# 393
# Iteration 12: Best cost = 1332.3152684015936
# 296
# 45.0
# 393
# 119
# 97
# 57.43416490252569
# 105
# 196
# 303
# 57.43416490252569
# 105
# 196
# 458
# 296
# 303
# Iteration 13: Best cost = 1332.3152684015936
# 274
# 105
# 97
# 57.43416490252569
# 105
# 119
# 176
# 395
# 105
# 210
# 196
# 379
# 213
# 378
# 119
# Iteration 14: Best cost = 1332.3152684015936
# 41.622776601683796
# 57.43416490252569
# 303
# 213
# 97
# 295
# 303
# 196
# 119
# 303
# 293
# 303
# 105
# 394
# 97
# Iteration 15: Best cost = 1332.3152684015936
# 97
# 196
# 57.43416490252569
# 109.0
# 394
# 213
# 119
# 45.0
# 119
# 196
# 119
# 119
# 57.43416490252569
# 97
# 40.80584360149872
# Iteration 16: Best cost = 1332.3152684015936
# 378
# 119
# 206
# 213
# 196
# 119
# 119
# 189
# 40.80584360149872
# 119
# 303
# 196
# 119
# 296
# 119
# Iteration 17: Best cost = 1332.3152684015936
# 57.43416490252569
# 210
# 288
# 395
# 393
# 393
# 119
# 95
# 395
# 189
# 119
# 213
# 213
# 397
# 206
# Iteration 18: Best cost = 1332.3152684015936
# 303
# 119
# 41.622776601683796
# 397
# 97
# 213
# 57.43416490252569
# 288
# 119
# 119
# 210
# 105
# 210
# 288
# 378
# Iteration 19: Best cost = 1295.4153749701454
# 196
# 303
# 303
# 57.43416490252569
# 57.43416490252569
# 395
# 105
# 119
# 189
# 119
# 132.0
# 196
# 132.0
# 395
# 57.43416490252569
# Iteration 20: Best cost = 1295.4153749701454
# 119
# 119
# 393
# 303
# 57.43416490252569
# 57.43416490252569
# 295
# 295
# 40.80584360149872
# 288
# 303
# 119
# 293
# 119
# 105
# Iteration 21: Best cost = 1295.4153749701454
# 303
# 395
# 378
# 45.0
# 213
# 119
# 303
# 189
# 213
# 296
# 45.0
# 97
# 105
# 196
# 393
# Iteration 22: Best cost = 1295.4153749701454
# 189
# 295
# 213
# 97
# 97
# 206
# 57.43416490252569
# 119
# 119
# 206
# 119
# 57.43416490252569
# 213
# 206
# 213
# Iteration 23: Best cost = 1295.4153749701454
# 395
# 41.622776601683796
# 395
# 189
# 303
# 295
# 109
# 189
# 119
# 119
# 213
# 132.0
# 57.43416490252569
# 119
# 303
# Iteration 24: Best cost = 1295.4153749701454
# 395
# 119
# 196
# 394
# 293
# 119
# 196
# 189
# 303
# 295
# 119
# 296
# 303
# 119
# 288
# Iteration 25: Best cost = 1295.4153749701454
# 213
# 213
# 206
# 213
# 303
# 296
# 183
# 288
# 213
# 132.0
# 296
# 119
# 119
# 105
# 119
# Iteration 26: Best cost = 1295.4153749701454
# 296
# 176
# 119
# 196
# 378
# 57.43416490252569
# 189
# 119
# 393
# 275
# 189
# 119
# 303
# 296
# 189
# Iteration 27: Best cost = 1295.4153749701454
# 296
# 119
# 210
# 303
# 296
# 395
# 210
# 57.43416490252569
# 105
# 196
# 213
# 196
# 97
# 57.43416490252569
# 109
# Iteration 28: Best cost = 1295.4153749701454
# 57.43416490252569
# 213
# 97
# 45.0
# 45.0
# 189
# 57.43416490252569
# 213
# 296
# 97
# 196
# 303
# 303
# 57.43416490252569
# 213
# Iteration 29: Best cost = 1295.4153749701454
# 213
# 213
# 105
# 105
# 395
# 303
# 295
# 210
# 213
# 210
# 119
# 45.0
# 213
# 109
# 295
# Iteration 30: Best cost = 1295.4153749701454
# 213
# 196
# 119
# 119
# 105
# 119
# 105
# 303
# 189
# 183
# 109
# 40.80584360149872
# 293
# 296
# 45.0
# Iteration 31: Best cost = 1295.4153749701454
# 395
# 213
# 210
# 288
# 288
# 45.0
# 213
# 210
# 189
# 206
# 293
# 119
# 378
# 57.43416490252569
# 109
# Iteration 32: Best cost = 1295.4153749701454
# 99.06555764955334
# 109
# 119
# 57.43416490252569
# 213
# 295
# 119
# 303
# 296
# 189
# 303
# 109
# 119
# 378
# 293
# Iteration 33: Best cost = 1295.4153749701454
# 97
# 213
# 40.80584360149872
# 295
# 303
# 119
# 275
# 293
# 97
# 57.43416490252569
# 57.43416490252569
# 213
# 293
# 210
# 189
# Iteration 34: Best cost = 1295.4153749701454
# 303
# 293
# 303
# 296
# 213
# 296
# 303
# 183
# 303
# 119
# 288
# 378
# 57.43416490252569
# 213
# 303
# Iteration 35: Best cost = 1295.4153749701454
# 57.43416490252569
# 109
# 295
# 210
# 213
# 210
# 293
# 378
# 213
# 78
# 206
# 303
# 196
# 295
# 378
# Iteration 36: Best cost = 1295.4153749701454
# 40.80584360149872
# 105
# 45.0
# 119
# 213
# 295
# 213
# 210
# 213
# 303
# 296
# 206
# 303
# 119
# 393
# Iteration 37: Best cost = 1295.4153749701454
# 119
# 213
# 393
# 213
# 296
# 105
# 189
# 119
# 303
# 45.0
# 296
# 213
# 210
# 213
# 394
# Iteration 38: Best cost = 1295.4153749701454
# 293
# 288
# 97
# 303
# 97
# 213
# 213
# 119
# 189
# 293
# 119
# 213
# 213
# 213
# 41.622776601683796
# Iteration 39: Best cost = 1295.4153749701454
# 41.622776601683796
# 105
# 296
# 119
# 275
# 213
# 378
# 119
# 213
# 213
# 393
# 213
# 393
# 303
# 303
# Iteration 40: Best cost = 1295.4153749701454
# 213
# 293
# 296
# 196
# 303
# 57.43416490252569
# 288
# 210
# 119
# 210
# 119
# 394
# 57.43416490252569
# 293
# 210
# Iteration 41: Best cost = 1241.948329622992
# 57.43416490252569
# 119
# 271
# 132.0
# 97
# 213
# 303
# 213
# 213
# 196
# 295
# 189
# 368
# 296
# 57.43416490252569
# Iteration 42: Best cost = 1241.948329622992
# 303
# 395
# 395
# 288
# 105
# 105
# 303
# 288
# 378
# 196
# 119
# 213
# 378
# 132.0
# 206
# Iteration 43: Best cost = 1241.948329622992
# 295
# 57.43416490252569
# 57.43416490252569
# 303
# 394
# 210
# 295
# 213
# 105
# 119
# 293
# 303
# 303
# 303
# 196
# Iteration 44: Best cost = 1241.948329622992
# 105
# 196
# 119
# 303
# 295
# 395
# 295
# 213
# 105
# 119
# 288
# 45.0
# 119
# 303
# 296
# Iteration 45: Best cost = 1241.948329622992
# 397
# 132.0
# 395
# 213
# 57.43416490252569
# 213
# 109
# 295
# 119
# 213
# 189
# 210
# 213
# 206
# 395
# Iteration 46: Best cost = 1241.948329622992
# 132.0
# 296
# 45.0
# 213
# 57.43416490252569
# 293
# 119
# 303
# 97
# 295
# 213
# 295
# 210
# 288
# 40.80584360149872
# Iteration 47: Best cost = 1241.948329622992
# 97
# 206
# 288
# 119
# 288
# 119
# 303
# 213
# 210
# 119
# 303
# 213
# 213
# 132.0
# 303
# Iteration 48: Best cost = 1241.948329622992
# 393
# 105
# 303
# 296
# 105
# 97
# 109
# 105
# 293
# 213
# 105
# 303
# 303
# 45.0
# 119
# Iteration 49: Best cost = 1241.948329622992
# 213
# 295
# 119
# 288
# 189
# 213
# 119
# 119
# 213
# 213
# 303
# 303
# 119
# 119
# 213
# Iteration 50: Best cost = 1241.948329622992
# 119
# 393
# 213
# 189
# 196
# 45.0
# 213
# 303
# 303
# 293
# 296
# 288
# 119
# 119
# 119
# Iteration 51: Best cost = 1241.948329622992
# 213
# 132.0
# 213
# 378
# 295
# 369
# 394
# 57.43416490252569
# 45.0
# 368
# 97
# 213
# 41.622776601683796
# 45.0
# 57.43416490252569
# Iteration 52: Best cost = 1241.948329622992
# 206
# 303
# 119
# 303
# 303
# 206
# 213
# 57.43416490252569
# 213
# 394
# 105
# 119
# 397
# 196
# 210
# Iteration 53: Best cost = 1241.948329622992
# 296
# 210
# 45.0
# 57.43416490252569
# 119
# 119
# 132.0
# 210
# 295
# 196
# 189
# 57.43416490252569
# 119
# 45.0
# 303
# Iteration 54: Best cost = 1241.948329622992
# 288
# 213
# 105
# 109
# 210
# 189
# 213
# 379
# 97
# 119
# 303
# 57.43416490252569
# 296
# 288
# 296
# Iteration 55: Best cost = 1241.948329622992
# 119
# 295
# 295
# 295
# 119
# 303
# 119
# 213
# 183
# 206
# 119
# 119
# 57.43416490252569
# 45.0
# 109
# Iteration 56: Best cost = 1241.948329622992
# 288
# 288
# 296
# 295
# 213
# 288
# 213
# 288
# 196
# 303
# 41.622776601683796
# 132.0
# 303
# 213
# 97
# Iteration 57: Best cost = 1241.948329622992
# 119
# 303
# 303
# 295
# 196
# 288
# 303
# 119
# 210
# 119
# 206
# 288
# 296
# 119
# 109
# Iteration 58: Best cost = 1241.948329622992
# 119
# 196
# 57.43416490252569
# 105
# 119
# 119
# 303
# 213
# 196
# 206
# 119
# 213
# 213
# 119
# 45.0
# Iteration 59: Best cost = 1241.948329622992
# 57.43416490252569
# 397
# 295
# 105
# 395
# 303
# 57.43416490252569
# 119
# 288
# 132.0
# 206
# 210
# 303
# 189
# 40.80584360149872
# Iteration 60: Best cost = 1241.948329622992
# 288
# 295
# 119
# 40.80584360149872
# 303
# 45.0
# 119
# 295
# 296
# 109
# 105
# 303
# 303
# 295
# 288
# Iteration 61: Best cost = 1200.692582263488
# 303
# 105
# 303
# 288
# 132.0
# 119
# 206
# 57.43416490252569
# 57.43416490252569
# 57.43416490252569
# 394
# 119
# 295
# 397
# 303
# Iteration 62: Best cost = 1200.692582263488
# 45.0
# 213
# 109
# 378
# 109
# 105
# 119
# 57.43416490252569
# 109
# 97
# 119
# 210
# 105
# 57.43416490252569
# 206
# Iteration 63: Best cost = 1200.692582263488
# 213
# 395
# 40.80584360149872
# 189
# 303
# 189
# 295
# 57.43416490252569
# 105
# 213
# 119
# 105
# 288
# 303
# 119
# Iteration 64: Best cost = 1200.692582263488
# 119
# 119
# 189
# 303
# 119
# 196
# 394
# 119
# 206
# 303
# 296
# 105
# 97
# 303
# 105
# Iteration 65: Best cost = 1200.692582263488
# 395
# 97
# 213
# 132.0
# 57.43416490252569
# 303
# 45.0
# 57.43416490252569
# 303
# 293
# 40.80584360149872
# 57.43416490252569
# 119
# 296
# 213
# Iteration 66: Best cost = 1200.692582263488
# 210
# 196
# 105
# 303
# 105
# 97
# 95
# 210
# 196
# 296
# 41.622776601683796
# 45.0
# 97
# 206
# 213
# Iteration 67: Best cost = 1200.692582263488
# 189
# 119
# 105
# 395
# 40.80584360149872
# 303
# 119
# 378
# 119
# 41.622776601683796
# 303
# 105
# 109
# 119
# 288
# Iteration 68: Best cost = 1200.692582263488
# 296
# 45.0
# 109
# 213
# 179
# 303
# 57.43416490252569
# 119
# 293
# 105
# 132.0
# 57.43416490252569
# 303
# 57.43416490252569
# 368
# Iteration 69: Best cost = 1200.692582263488
# 303
# 189
# 125.43157642872126
# 210
# 394
# 109
# 213
# 119
# 105
# 213
# 189
# 288
# 210
# 394
# 213
# Iteration 70: Best cost = 1200.692582263488
# 378
# 296
# 213
# 57.43416490252569
# 295
# 119
# 303
# 57.43416490252569
# 40.80584360149872
# 303
# 213
# 213
# 196
# 119
# 288
# Iteration 71: Best cost = 1200.692582263488
# 57.43416490252569
# 57.43416490252569
# 119
# 105
# 296
# 119
# 189
# 97
# 378
# 213
# 303
# 288
# 119
# 397
# 303
# Iteration 72: Best cost = 1200.692582263488
# 119
# 57.43416490252569
# 303
# 397
# 105
# 57.43416490252569
# 394
# 41.622776601683796
# 196
# 119
# 288
# 288
# 109
# 213
# 213
# Iteration 73: Best cost = 1200.692582263488
# 119
# 105
# 378
# 210
# 303
# 213
# 206
# 293
# 394
# 397
# 109
# 303
# 40.80584360149872
# 275
# 213
# Iteration 74: Best cost = 1200.692582263488
# 213
# 45.0
# 119
# 210
# 119
# 288
# 303
# 105
# 206
# 119
# 213
# 303
# 296
# 57.43416490252569
# 105
# Iteration 75: Best cost = 1200.692582263488
# 189
# 213
# 395
# 206
# 213
# 109
# 119
# 213
# 40.80584360149872
# 132.0
# 394
# 303
# 295
# 296
# 303
# Iteration 76: Best cost = 1200.692582263488
# 213
# 395
# 196
# 393
# 105
# 196
# 119
# 119
# 288
# 303
# 303
# 296
# 41.622776601683796
# 206
# 97
# Iteration 77: Best cost = 1200.692582263488
# 57.43416490252569
# 119
# 109
# 119
# 394
# 57.43416490252569
# 45.0
# 296
# 206
# 288
# 104.24428900898053
# 295
# 57.43416490252569
# 132.0
# 119
# Iteration 78: Best cost = 1200.692582263488
# 397
# 303
# 394
# 189
# 119
# 296
# 303
# 57.43416490252569
# 213
# 119
# 394
# 303
# 105
# 189
# 213
# Iteration 79: Best cost = 1200.692582263488
# 97
# 296
# 293
# 97
# 295
# 105
# 210
# 213
# 393
# 119
# 303
# 210.43157642872126
# 105
# 41.622776601683796
# 119
# Iteration 80: Best cost = 1200.692582263488
# 45.0
# 210
# 119
# 303
# 303
# 40.80584360149872
# 57.43416490252569
# 210
# 303
# 57.43416490252569
# 105
# 57.43416490252569
# 119
# 393
# 132.0
# Iteration 81: Best cost = 1200.692582263488
# 57.43416490252569
# 303
# 213
# 206
# 119
# 288
# 303
# 119
# 119
# 189
# 293
# 105
# 119
# 210
# 132.0
# Iteration 82: Best cost = 1200.692582263488
# 119
# 57.43416490252569
# 132.0
# 132.0
# 57.43416490252569
# 293
# 210
# 293
# 97
# 213
# 213
# 40.80584360149872
# 210
# 119
# 213
# Iteration 83: Best cost = 1200.692582263488
# 57.43416490252569
# 303
# 119
# 119
# 210
# 119
# 393
# 246.6078810084939
# 196
# 45.0
# 119
# 97
# 57.43416490252569
# 303
# 213
# Iteration 84: Best cost = 1200.692582263488
# 213
# 119
# 132.0
# 105
# 119
# 97
# 109
# 40.80584360149872
# 206
# 105
# 119
# 119
# 379
# 213
# 196
# Iteration 85: Best cost = 1200.692582263488
# 275
# 210
# 105
# 206
# 45.0
# 303
# 293
# 57.43416490252569
# 295
# 206
# 296
# 196
# 213
# 393
# 213
# Iteration 86: Best cost = 1200.692582263488
# 246.6078810084939
# 57.43416490252569
# 119
# 213
# 303
# 57.43416490252569
# 90.67402498121706
# 303
# 132.0
# 105
# 213
# 303
# 206
# 206
# 57.43416490252569
# Iteration 87: Best cost = 1200.692582263488
# 395
# 213
# 395
# 119
# 303
# 119
# 395
# 206
# 119
# 104.24428900898053
# 119
# 210
# 210
# 109
# 293
# Iteration 88: Best cost = 1200.692582263488
# 132.0
# 206
# 119
# 303
# 196
# 45.0
# 57.43416490252569
# 57.43416490252569
# 97
# 119
# 109
# 288
# 189
# 378
# 105
# Iteration 89: Best cost = 1200.692582263488
# 119
# 119
# 368
# 132.0
# 288
# 210
# 30.615528128088304
# 132.0
# 105
# 213
# 119
# 57.43416490252569
# 210
# 296
# 119
# Iteration 90: Best cost = 1200.692582263488
# 210
# 132.0
# 119
# 119
# 196
# 119
# 105
# 206
# 293
# 45.0
# 57.43416490252569
# 105
# 40.80584360149872
# 395
# 395
# Iteration 91: Best cost = 1200.692582263488
# 395
# 213
# 105
# 105
# 132.0
# 303
# 119
# 105
# 57.43416490252569
# 168.0
# 57.43416490252569
# 210
# 57.43416490252569
# 303
# 213
# Iteration 92: Best cost = 1200.692582263488
# 57.43416490252569
# 458
# 189
# 378
# 97
# 213
# 293
# 40.80584360149872
# 132.0
# 105
# 40.80584360149872
# 210
# 303
# 213
# 288
# Iteration 93: Best cost = 1200.692582263488
# 119
# 125.43157642872126
# 303
# 206
# 105
# 40.80584360149872
# 109
# 40.80584360149872
# 213
# 183
# 119
# 119
# 303
# 288
# 105
# Iteration 94: Best cost = 1200.692582263488
# 57.43416490252569
# 105
# 40.80584360149872
# 395
# 288
# 303
# 119
# 303
# 296
# 41.622776601683796
# 210
# 105
# 213
# 119
# 293
# Iteration 95: Best cost = 1200.692582263488
# 57.43416490252569
# 288
# 206
# 40.80584360149872
# 97
# 395
# 393
# 213
# 45.0
# 105
# 119
# 303
# 132.0
# 97
# 57.43416490252569
# Iteration 96: Best cost = 1200.692582263488
# 210
# 109
# 105
# 45.0
# 109
# 378
# 119
# 119
# 213
# 45.0
# 213
# 126.78925849354833
# 57.43416490252569
# 132.0
# 119
# Iteration 97: Best cost = 1200.692582263488
# 397
# 109
# 206
# 105
# 57.43416490252569
# 213
# 109
# 394
# 293
# 57.43416490252569
# 189
# 57.43416490252569
# 303
# 295
# 196
# Iteration 98: Best cost = 1200.692582263488
# 393
# 105
# 45.0
# 288
# 119
# 213
# 45.0
# 97
# 97
# 394
# 395
# 303
# 105
# 210
# 119
# Iteration 99: Best cost = 1200.692582263488
# 41.622776601683796
# 210
# 40.80584360149872
# 119
# 105
# 293
# 40.80584360149872
# 303
# 288
# 119
# 303
# 105
# 397
# 213
# 213
# Iteration 100: Best cost = 1200.692582263488
# 395
# 213
# 109
# 213
# 303
# 57.43416490252569
# 196
# 119
# 395
# 40.80584360149872
# 210
# 97
# 303
# 303
# 109
# Iteration 101: Best cost = 1200.692582263488
# 45.0
# 119
# 45.0
# 288
# 303
# 296
# 303
# 213
# 45.0
# 213
# 119
# 97
# 395
# 303
# 105
# Iteration 102: Best cost = 1200.692582263488
# 296
# 119
# 293
# 132.0
# 293
# 189
# 394
# 119
# 303
# 213
# 105
# 295
# 213
# 119
# 45.0
# Iteration 103: Best cost = 1200.692582263488
# 213
# 196
# 295
# 395
# 303
# 303
# 303
# 303
# 303
# 57.43416490252569
# 303
# 189
# 119
# 139.78925849354835
# 57.43416490252569
# Iteration 104: Best cost = 1200.692582263488
# 303
# 45.0
# 296
# 288
# 293
# 105
# 210
# 213
# 303
# 296
# 105
# 213
# 45.0
# 189
# 189
# Iteration 105: Best cost = 1200.692582263488
# 213
# 57.43416490252569
# 395
# 303
# 395
# 109
# 119
# 213
# 293
# 45.0
# 213
# 119
# 303
# 213
# 119
# Iteration 106: Best cost = 1200.692582263488
# 210
# 393
# 119
# 295
# 119
# 293
# 288
# 105
# 288
# 303
# 206
# 105
# 57.43416490252569
# 105
# 57.43416490252569
# Iteration 107: Best cost = 1200.692582263488
# 303
# 295
# 213
# 119
# 132.0
# 119
# 303
# 189
# 119
# 119
# 119
# 97
# 303
# 57.43416490252569
# 295
# Iteration 108: Best cost = 1200.692582263488
# 40.80584360149872
# 213
# 109
# 45.0
# 303
# 213
# 378
# 213
# 210
# 303
# 41.622776601683796
# 57.43416490252569
# 119
# 105
# 119
# Iteration 109: Best cost = 1200.692582263488
# 41.622776601683796
# 393
# 119
# 45.0
# 288
# 296
# 105
# 206
# 97
# 213
# 296
# 395
# 119
# 41.622776601683796
# 288
# Iteration 110: Best cost = 1200.692582263488
# 119
# 213
# 378
# 303
# 303
# 45.0
# 210
# 303
# 119
# 105
# 189
# 119
# 378
# 288
# 210
# Iteration 111: Best cost = 1200.692582263488
# 45.0
# 288
# 213
# 119
# 210
# 296
# 303
# 296
# 303
# 132.0
# 303
# 189
# 189
# 119
# 303
# Iteration 112: Best cost = 1200.692582263488
# 119
# 296
# 119
# 206
# 57.43416490252569
# 119
# 210
# 303
# 41.622776601683796
# 293
# 303
# 119
# 378
# 213
# 206
# Iteration 113: Best cost = 1200.692582263488
# 303
# 296
# 395
# 210
# 210
# 119
# 40.80584360149872
# 41.622776601683796
# 378
# 303
# 303
# 40.80584360149872
# 196
# 296
# 378
# Iteration 114: Best cost = 1200.692582263488
# 397
# 57.43416490252569
# 303
# 119
# 97
# 45.0
# 139.78925849354835
# 97
# 119
# 303
# 119
# 40.80584360149872
# 378
# 213
# 57.43416490252569
# Iteration 115: Best cost = 1200.692582263488
# 57.43416490252569
# 109
# 295
# 196
# 293
# 303
# 119
# 210
# 303
# 57.43416490252569
# 303
# 378
# 394
# 40.80584360149872
# 105
# Iteration 116: Best cost = 1200.692582263488
# 196
# 119
# 303
# 189
# 210
# 196
# 213
# 213
# 303
# 395
# 213
# 119
# 293
# 105
# 57.43416490252569
# Iteration 117: Best cost = 1200.692582263488
# 288
# 303
# 105
# 393
# 213
# 206
# 213
# 296
# 97
# 119
# 97
# 119
# 210
# 119
# 295
# Iteration 118: Best cost = 1200.692582263488
# 40.80584360149872
# 119
# 57.43416490252569
# 119
# 303
# 213
# 210
# 45.0
# 395
# 213
# 196
# 57.43416490252569
# 132.0
# 119
# 196
# Iteration 119: Best cost = 1200.692582263488
# 40.80584360149872
# 45.0
# 57.43416490252569
# 41.622776601683796
# 293
# 97
# 97
# 97
# 394
# 97
# 213
# 206
# 57.43416490252569
# 210
# 213
# Iteration 120: Best cost = 1200.692582263488
# 105
# 303
# 288
# 206
# 196
# 295
# 45.0
# 303
# 57.43416490252569
# 57.43416490252569
# 213
# 210
# 45.0
# 97
# 206
# Iteration 121: Best cost = 1200.692582263488
# 119
# 119
# 97
# 303
# 97
# 105
# 57.43416490252569
# 213
# 119
# 295
# 119
# 57.43416490252569
# 196
# 213
# 97
# Iteration 122: Best cost = 1200.692582263488
# 97
# 295
# 45.0
# 97
# 57.43416490252569
# 119
# 119
# 40.80584360149872
# 119
# 206
# 210
# 105
# 213
# 57.43416490252569
# 119
# Iteration 123: Best cost = 1200.692582263488
# 395
# 97
# 206
# 378
# 57.43416490252569
# 40.80584360149872
# 213
# 210
# 97
# 57.43416490252569
# 105
# 210
# 210
# 213
# 213
# Iteration 124: Best cost = 1200.692582263488
# 303
# 210
# 206
# 119
# 97
# 109
# 210
# 303
# 105
# 303
# 40.80584360149872
# 57.43416490252569
# 119
# 97
# 213
# Iteration 125: Best cost = 1200.692582263488
# 40.80584360149872
# 45.0
# 206
# 303
# 132.0
# 206
# 105
# 210
# 119
# 213
# 119
# 393
# 206
# 395
# 119
# Iteration 126: Best cost = 1200.692582263488
# 189
# 40.80584360149872
# 109.0
# 119
# 303
# 213
# 41.622776601683796
# 210
# 97
# 213
# 119
# 293
# 105
# 303
# 45.0
# Iteration 127: Best cost = 1200.692582263488
# 210
# 57.43416490252569
# 119
# 119
# 210
# 105
# 378
# 45.0
# 189
# 45.0
# 213
# 210
# 97
# 394
# 213
# Iteration 128: Best cost = 1200.692582263488
# 210
# 97
# 57.43416490252569
# 109.0
# 57.43416490252569
# 119
# 119
# 105
# 97
# 94.05124837953326
# 119
# 397
# 296
# 57.43416490252569
# 119
# Iteration 129: Best cost = 1200.692582263488
# 303
# 109
# 210
# 109
# 105
# 57.43416490252569
# 119
# 210
# 394
# 206
# 189
# 210
# 139.78925849354835
# 213
# 57.43416490252569
# Iteration 130: Best cost = 1200.692582263488
# 45.0
# 41.622776601683796
# 97
# 105
# 97
# 303
# 189
# 97
# 41.622776601683796
# 97
# 397
# 378
# 303
# 213
# 57.43416490252569
# Iteration 131: Best cost = 1200.692582263488
# 288
# 109
# 303
# 210
# 109
# 196
# 303
# 125.43157642872126
# 378
# 189
# 397
# 40.80584360149872
# 458
# 57.43416490252569
# 105
# Iteration 132: Best cost = 1200.692582263488
# 97
# 57.43416490252569
# 119
# 57.43416490252569
# 119
# 213
# 97
# 196
# 196
# 119
# 97
# 395
# 119
# 105
# 295
# Iteration 133: Best cost = 1200.692582263488
# 210
# 97
# 119
# 97
# 57.43416490252569
# 57.43416490252569
# 288
# 488
# 132.0
# 210
# 213
# 303
# 210
# 293
# 57.43416490252569
# Iteration 134: Best cost = 1200.692582263488
# 189
# 303
# 138.43157642872126
# 303
# 196
# 57.43416490252569
# 206
# 105
# 97
# 57.43416490252569
# 119
# 303
# 119
# 109.0
# 105
# Iteration 135: Best cost = 1200.692582263488
# 295
# 196
# 210
# 57.43416490252569
# 395
# 105
# 45.0
# 395
# 206
# 303
# 119
# 395
# 95
# 196
# 213
# Iteration 136: Best cost = 1200.692582263488
# 57.43416490252569
# 303
# 213
# 119
# 213
# 213
# 97
# 303
# 109.0
# 293
# 189
# 213
# 57.43416490252569
# 41.622776601683796
# 97
# Iteration 137: Best cost = 1200.692582263488
# 303
# 303
# 45.0
# 303
# 206
# 210
# 296
# 210
# 295
# 189
# 210
# 210
# 213
# 105
# 119
# Iteration 138: Best cost = 1200.692582263488
# 109
# 119
# 41.622776601683796
# 206
# 109
# 213
# 288
# 119
# 97
# 105
# 213
# 213
# 119
# 109
# 45.0
# Iteration 139: Best cost = 1200.692582263488
# 41.622776601683796
# 213
# 109
# 213
# 105
# 57.43416490252569
# 226.43157642872126
# 303
# 119
# 119
# 119
# 119
# 119
# 303
# 45.0
# Iteration 140: Best cost = 1200.692582263488
# 109.0
# 206
# 213
# 210
# 206
# 57.43416490252569
# 40.80584360149872
# 119
# 40.80584360149872
# 288
# 57.43416490252569
# 119
# 210
# 109
# 213
# Iteration 141: Best cost = 1200.692582263488
# 97
# 296
# 57.43416490252569
# 119
# 45.0
# 45.0
# 97
# 210
# 40.80584360149872
# 303
# 132.0
# 119
# 206
# 57.43416490252569
# 303
# Iteration 142: Best cost = 1200.692582263488
# 303
# 378
# 119
# 288
# 97
# 40.80584360149872
# 196
# 303
# 57.43416490252569
# 57.43416490252569
# 295
# 119
# 196
# 105
# 210
# Iteration 143: Best cost = 1200.692582263488
# 57.43416490252569
# 97
# 369
# 395
# 395
# 105
# 57.43416490252569
# 105
# 104.24428900898053
# 303
# 303
# 206
# 119
# 394
# 378
# Iteration 144: Best cost = 1200.692582263488
# 189
# 40.80584360149872
# 303
# 210
# 213
# 213
# 379
# 196
# 119
# 288
# 288
# 109
# 105
# 394
# 41.622776601683796
# Iteration 145: Best cost = 1200.692582263488
# 303
# 397
# 213
# 105
# 57.43416490252569
# 97
# 189
# 213
# 213
# 40.80584360149872
# 119
# 45.0
# 296
# 57.43416490252569
# 105
# Iteration 146: Best cost = 1200.692582263488
# 40.80584360149872
# 189
# 288
# 119
# 119
# 45.0
# 303
# 394
# 303
# 210
# 210
# 45.0
# 105
# 206
# 119
# Iteration 147: Best cost = 1200.692582263488
# 119
# 105
# 119
# 213
# 57.43416490252569
# 45.0
# 109
# 196
# 105
# 288
# 57.43416490252569
# 119
# 394
# 57.43416490252569
# 213
# Iteration 148: Best cost = 1200.692582263488
# 213
# 138.43157642872126
# 213
# 40.80584360149872
# 45.0
# 213
# 97
# 119
# 105
# 303
# 303
# 57.43416490252569
# 109.0
# 97
# 119
# Iteration 149: Best cost = 1200.692582263488
# 196
# 293
# 210
# 119
# 97
# 210
# 119
# 189
# 57.43416490252569
# 296
# 210
# 119
# 378
# 119
# 295
# Iteration 150: Best cost = 1200.692582263488
# 303
# 132.0
# 213
# 119
# 119
# 378
# 293
# 210
# 105
# 213
# 105
# 109.0
# 295
# 210
# 295
# Iteration 151: Best cost = 1200.692582263488
# 45.0
# 105
# 210
# 109.0
# 303
# 119
# 119
# 105
# 295
# 119
# 105
# 97
# 97
# 57.43416490252569
# 57.43416490252569
# Iteration 152: Best cost = 1200.692582263488
# 57.43416490252569
# 41.622776601683796
# 213
# 210
# 41.622776601683796
# 45.0
# 97
# 196
# 303
# 132.0
# 213
# 303
# 213
# 213
# 119
# Iteration 153: Best cost = 1200.692582263488
# 119
# 296
# 57.43416490252569
# 210
# 378
# 303
# 303
# 296
# 213
# 119
# 196
# 196
# 119
# 45.0
# 119
# Iteration 154: Best cost = 1200.692582263488
# 119
# 105
# 119
# 40.80584360149872
# 119
# 119
# 97
# 213
# 213
# 196
# 395
# 296
# 213
# 57.43416490252569
# 378
# Iteration 155: Best cost = 1200.692582263488
# 288
# 119
# 40.80584360149872
# 57.43416490252569
# 303
# 397
# 119
# 296
# 105
# 293
# 210
# 189
# 213
# 206
# 189
# Iteration 156: Best cost = 1200.692582263488
# 378
# 119
# 210
# 57.43416490252569
# 296
# 213
# 395
# 119
# 57.43416490252569
# 189
# 189
# 119
# 296
# 210
# 213
# Iteration 157: Best cost = 1200.692582263488
# 394
# 97
# 119
# 119
# 296
# 45.0
# 206
# 97
# 213
# 296
# 119
# 119
# 213
# 57.43416490252569
# 119
# Iteration 158: Best cost = 1200.692582263488
# 293
# 109.0
# 189
# 213
# 213
# 105
# 189
# 119
# 213
# 57.43416490252569
# 303
# 395
# 97
# 196
# 213
# Iteration 159: Best cost = 1200.692582263488
# 206
# 57.43416490252569
# 206
# 303
# 189
# 97
# 57.43416490252569
# 97
# 119
# 119
# 303
# 132.0
# 288
# 105
# 45.0
# Iteration 160: Best cost = 1200.692582263488
# 213
# 296
# 213
# 119
# 288
# 213
# 119
# 97
# 288
# 196
# 303
# 57.43416490252569
# 119
# 213
# 105
# Iteration 161: Best cost = 1200.692582263488
# 105
# 213
# 119
# 288
# 105
# 105
# 189
# 213
# 295
# 132.0
# 45.0
# 393
# 119
# 210
# 119
# Iteration 162: Best cost = 1200.692582263488
# 303
# 132.0
# 40.80584360149872
# 119
# 109.0
# 119
# 296
# 105
# 213
# 97
# 210
# 210
# 213
# 213
# 213
# Iteration 163: Best cost = 1200.692582263488
# 213
# 45.0
# 303
# 213
# 303
# 119
# 97
# 109
# 303
# 41.622776601683796
# 119
# 213
# 119
# 119
# 210
# Iteration 164: Best cost = 1200.692582263488
# 213
# 303
# 213
# 395
# 303
# 119
# 210
# 97
# 138.43157642872126
# 109.0
# 303
# 119
# 288
# 303
# 119
# Iteration 165: Best cost = 1200.692582263488
# 119
# 206
# 119
# 105
# 119
# 41.622776601683796
# 40.80584360149872
# 213
# 213
# 303
# 295
# 303
# 189
# 119
# 119
# Iteration 166: Best cost = 1200.692582263488
# 213
# 213
# 395
# 119
# 40.80584360149872
# 119
# 105
# 119
# 119
# 119
# 189
# 119
# 213
# 57.43416490252569
# 189
# Iteration 167: Best cost = 1200.692582263488
# 303
# 45.0
# 293
# 395
# 57.43416490252569
# 288
# 97
# 57.43416490252569
# 57.43416490252569
# 303
# 295
# 210
# 213
# 394
# 40.80584360149872
# Iteration 168: Best cost = 1200.692582263488
# 119
# 303
# 57.43416490252569
# 213
# 119
# 303
# 57.43416490252569
# 109
# 303
# 288
# 213
# 295
# 296
# 189
# 105
# Iteration 169: Best cost = 1200.692582263488
# 295
# 303
# 296
# 45.0
# 57.43416490252569
# 109
# 41.622776601683796
# 57.43416490252569
# 296
# 109.0
# 394
# 45.0
# 378
# 57.43416490252569
# 213
# Iteration 170: Best cost = 1200.692582263488
# 378
# 206
# 196
# 57.43416490252569
# 296
# 40.80584360149872
# 57.43416490252569
# 288
# 57.43416490252569
# 213
# 196
# 378
# 105
# 213
# 183
# Iteration 171: Best cost = 1200.692582263488
# 105
# 196
# 296
# 293
# 397
# 393
# 196
# 395
# 393
# 189
# 40.80584360149872
# 105
# 296
# 213
# 296
# Iteration 172: Best cost = 1200.692582263488
# 206
# 206
# 105
# 395
# 210
# 57.43416490252569
# 393
# 109
# 303
# 213
# 296
# 206
# 189
# 213
# 303
# Iteration 173: Best cost = 1200.692582263488
# 303
# 395
# 119
# 119
# 213
# 196
# 303
# 119
# 196
# 189
# 303
# 303
# 189
# 303
# 295
# Iteration 174: Best cost = 1200.692582263488
# 213
# 119
# 57.43416490252569
# 213
# 303
# 213
# 213
# 288
# 288
# 295
# 105
# 105
# 213
# 213
# 213
# Iteration 175: Best cost = 1200.692582263488
# 144.5963317979674
# 189
# 210
# 183
# 97
# 379
# 132.0
# 119
# 105
# 393
# 196
# 109
# 119
# 189
# 105
# Iteration 176: Best cost = 1200.692582263488
# 119
# 213
# 210
# 119
# 57.43416490252569
# 303
# 196
# 213
# 210
# 213
# 119
# 296
# 57.43416490252569
# 288
# 213
# Iteration 177: Best cost = 1200.692582263488
# 213
# 57.43416490252569
# 119
# 119
# 378
# 119
# 295
# 105
# 296
# 105
# 213
# 119
# 45.0
# 293
# 119
# Iteration 178: Best cost = 1200.692582263488
# 394
# 132.0
# 109
# 213
# 105
# 41.622776601683796
# 119
# 303
# 119
# 105
# 119
# 189
# 41.622776601683796
# 196
# 295
# Iteration 179: Best cost = 1200.692582263488
# 119
# 378
# 295
# 296
# 196
# 213
# 296
# 213
# 40.80584360149872
# 105
# 41.622776601683796
# 119
# 213
# 206
# 119
# Iteration 180: Best cost = 1200.692582263488
# 213
# 57.43416490252569
# 293
# 393
# 119
# 57.43416490252569
# 296
# 189
# 119
# 206
# 119
# 105
# 295
# 206
# 397
# Iteration 181: Best cost = 1200.692582263488
# 40.80584360149872
# 303
# 125.43157642872126
# 97
# 189
# 40.80584360149872
# 295
# 210
# 41.622776601683796
# 97
# 293
# 303
# 293
# 105
# 119
# Iteration 182: Best cost = 1200.692582263488
# 303
# 378
# 119
# 395
# 303
# 119
# 57.43416490252569
# 210
# 119
# 57.43416490252569
# 303
# 109
# 213
# 213
# 213
# Iteration 183: Best cost = 1200.692582263488
# 303
# 189
# 293
# 109
# 296
# 397
# 97
# 213
# 119
# 288
# 105
# 213
# 40.80584360149872
# 57.43416490252569
# 213
# Iteration 184: Best cost = 1200.692582263488
# 213
# 105
# 97
# 119
# 109
# 303
# 119
# 303
# 393
# 213
# 132.0
# 296
# 57.43416490252569
# 393
# 57.43416490252569
# Iteration 185: Best cost = 1200.692582263488
# 57.43416490252569
# 213
# 303
# 119
# 57.43416490252569
# 293
# 41.622776601683796
# 213
# 213
# 97
# 97
# 288
# 303
# 288
# 132.0
# Iteration 186: Best cost = 1200.692582263488
# 296
# 57.43416490252569
# 105
# 206
# 296
# 213
# 57.43416490252569
# 206
# 303
# 213
# 394
# 213
# 119
# 275
# 57.43416490252569
# Iteration 187: Best cost = 1200.692582263488
# 296
# 288
# 213
# 41.622776601683796
# 119
# 213
# 109.0
# 303
# 210
# 57.43416490252569
# 295
# 393
# 395
# 119
# 378
# Iteration 188: Best cost = 1200.692582263488
# 271
# 213
# 296
# 132.0
# 303
# 119
# 393
# 109
# 210
# 293
# 295
# 206
# 296
# 213
# 378
# Iteration 189: Best cost = 1200.692582263488
# 40.80584360149872
# 210
# 105
# 296
# 213
# 378
# 109
# 206
# 288
# 296
# 119
# 296
# 303
# 189
# 196
# Iteration 190: Best cost = 1200.692582263488
# 57.43416490252569
# 213
# 395
# 57.43416490252569
# 213
# 206
# 189
# 196
# 213
# 293
# 105
# 109
# 119
# 296
# 213
# Iteration 191: Best cost = 1200.692582263488
# 213
# 213
# 206
# 213
# 378
# 196
# 293
# 210
# 303
# 119
# 303
# 303
# 213
# 295
# 97
# Iteration 192: Best cost = 1200.692582263488
# 213
# 132.0
# 196
# 213
# 119
# 213
# 109
# 296
# 213
# 210
# 119
# 119
# 213
# 395
# 119
# Iteration 193: Best cost = 1200.692582263488
# 213
# 213
# 119
# 105
# 296
# 394
# 196
# 303
# 105
# 296
# 57.43416490252569
# 119
# 303
# 119
# 119
# Iteration 194: Best cost = 1200.692582263488
# 57.43416490252569
# 45.0
# 293
# 296
# 57.43416490252569
# 213
# 296
# 293
# 139.78925849354835
# 57.43416490252569
# 105
# 295
# 57.43416490252569
# 393
# 40.80584360149872
# Iteration 195: Best cost = 1200.692582263488
# 213
# 213
# 303
# 303
# 303
# 293
# 196
# 40.80584360149872
# 57.43416490252569
# 213
# 395
# 132.0
# 210
# 196
# 57.43416490252569
# Iteration 196: Best cost = 1200.692582263488
# 119
# 393
# 119
# 296
# 296
# 288
# 288
# 196
# 97
# 293
# 213
# 393
# 119
# 303
# 206
# Iteration 197: Best cost = 1200.692582263488
# 119
# 105
# 119
# 213
# 397
# 57.43416490252569
# 210
# 213
# 196
# 105
# 378
# 179
# 57.43416490252569
# 45.0
# 105
# Iteration 198: Best cost = 1200.692582263488
# 378
# 119
# 119
# 119
# 293
# 119
# 213
# 213
# 57.43416490252569
# 213
# 295
# 109
# 97
# 119
# 57.43416490252569
# Iteration 199: Best cost = 1200.692582263488
# 196
# 395
# 97
# 105
# 271
# 213
# 293
# 41.622776601683796
# 303
# 303
# 97
# 119
# 395
# 189
# 368
# Iteration 200: Best cost = 1200.692582263488
# [[0, 20, 21, 52, 49, 47, 0], [0, 67, 65, 63, 62, 74, 72, 61, 64, 68, 66, 69, 0], [0, 24, 25, 27, 29, 30, 28, 26, 23, 22, 50, 1, 75, 0], [0, 5, 3, 7, 8, 9, 6, 4, 2, 91, 0], [0, 10, 11, 16, 14, 12, 100, 99, 89, 0], [0, 81, 78, 76, 71, 70, 73, 77, 79, 80, 0], [0, 57, 55, 54, 53, 56, 58, 60, 59, 0], [0, 43, 42, 41, 40, 44, 45, 48, 51, 34, 0], [0, 90, 87, 86, 83, 82, 84, 85, 88, 0], [0, 32, 33, 31, 35, 37, 38, 39, 36, 0], [0, 98, 96, 95, 94, 92, 93, 97, 0], [0, 15, 46, 0], [0, 13, 17, 18, 19, 0]] 1200.692582263488
