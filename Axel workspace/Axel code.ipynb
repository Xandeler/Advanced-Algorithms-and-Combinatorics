# %%
from scipy.spatial import distance_matrix
import numpy as np
import matplotlib.pyplot as plt
import random
import math

dataset_name = 'c101'
file_path = '../2nd deliverable/solomon-100/'+dataset_name+'.txt'

# Initialize lists to store vehicle and customer data
vehicle_data = []
customer_data = []

# Read data line by line
with open(file_path, 'r') as file:
    lines = file.readlines()
    
    # Parse vehicle data
    vehicle_info_start = lines.index('VEHICLE\n') + 2
    customer_info_start = lines.index('CUSTOMER\n') + 2
    vehicle_line = lines[vehicle_info_start].strip().split()
    
    # Store vehicle data as a dictionary in a list
    vehicle_data.append({
        'NUMBER': int(vehicle_line[0]),
        'CAPACITY': int(vehicle_line[1])
    })
    
    # Parse customer data
    for line in lines[customer_info_start:]:
        if line.strip():  # Skip any empty lines
            parts = line.strip().split()
            customer_data.append({
                'CUST_NO': int(parts[0]),
                'XCOORD': int(parts[1]),
                'YCOORD': int(parts[2]),
                'DEMAND': int(parts[3]),
                'READY_TIME': int(parts[4]),
                'DUE_DATE': int(parts[5]),
                'SERVICE_TIME': int(parts[6])
            })

# %%
class Node:
    def __init__(self, id, x, y, demand, ready_time, due_date, service_time):
        self.id = id
        self.is_depot = (id == 0)
        self.x = x
        self.y = y
        self.demand = demand
        self.ready_time = ready_time
        self.due_date = due_date
        self.service_time = service_time
        self.service_time = 10
        self.visited = False
        
class Graph:
    def __init__(self, vehicle_data, customer_data):
        self.vehicle_data = vehicle_data
        self.customer_data = customer_data
        self.nodes = []
        self.vehicle_capacity = vehicle_data[0]['CAPACITY']
        self.num_vehicles = vehicle_data[0]['NUMBER']
        self.setup_nodes()
        self.setup_distance_matrix()
        self.initialize_pheromone_matrix()
        
    def setup_nodes(self):
        for customer in self.customer_data:
            node = Node(customer['CUST_NO'], customer['XCOORD'], customer['YCOORD'], customer['DEMAND'],
                        customer['READY_TIME'], customer['DUE_DATE'], customer['SERVICE_TIME'])
            self.nodes.append(node)
    
    def setup_distance_matrix(self):
        coords = [(node.x, node.y) for node in self.nodes]
        self.distance_matrix = distance_matrix(coords, coords)
        
    def initialize_pheromone_matrix(self):
        n = len(self.nodes)
        self.pheromone_matrix = [[1.0 for _ in range(n)] for _ in range(n)]
    
    def route_distance(self, route):
        distance = 0
        for i in range(len(route) - 1):
            distance += self.distance_matrix[route[i]][route[i + 1]]
        return distance
    
    def update_pheromones(self, ant_solutions, evaporation_rate=0.5):
        # Evaporate pheromones
        for i in range(len(self.pheromone_matrix)):
            for j in range(len(self.pheromone_matrix)):
                self.pheromone_matrix[i][j] = max(self.pheromone_matrix[i][j] * (1 - evaporation_rate), 1e-5)

        
        # Deposit pheromones based on ant solutions
        total_distance = sum(self.route_distance(route) for solution in ant_solutions for route in solution)
        for route in ant_solutions:
            for k in range(len(route) - 1):
                i, j = route[k], route[k + 1]
                self.pheromone_matrix[i][j] += (1 / self.route_distance(route)) / total_distance

# %%
def aco_vrp(G, num_ants, num_iterations, alpha=1.5, beta=2.5, evaporation_rate=0.5, q=100):
    """
    Ant Colony Optimization for Vehicle Routing Problem with Time Windows.
    """
    adj_matrix = G.distance_matrix
    capacity_max = G.vehicle_capacity
    num_points = adj_matrix.shape[0]
    ph_matrix = G.pheromone_matrix  # Initial pheromone matrix
    best_solution = None
    best_cost = float('inf')

    def calculate_probabilities(current_node, unvisited, current_time, current_capacity):
        """
        Calculate probabilities of moving to the next node considering time windows and capacity constraints.
        """
        attractiveness = []
        for neighbor in unvisited:
            travel_time = G.distance_matrix[current_node][neighbor]
            arrival_time = current_time + travel_time
            if (G.nodes[neighbor].demand + current_capacity <= capacity_max
                    and arrival_time <= G.nodes[neighbor].due_date):
                tau = ph_matrix[current_node][neighbor] ** alpha
                eta = (1.0 / G.distance_matrix[current_node][neighbor]) ** beta
                attractiveness.append(tau * eta)
            else:
                attractiveness.append(0)
        total = sum(attractiveness)
        if total == 0:  # Avoid division by zero
            return np.zeros(len(unvisited))
        return np.array(attractiveness) / total

    def construct_solution():
        routes = []
        back_time = []
        for node in G.nodes:
            node.visited = False

        while any(not node.visited for node in G.nodes[1:]):  # Exclude the depot
            current_node = 0  # Start at depot
            current_time = G.nodes[current_node].ready_time
            current_capacity = 0
            route = [current_node]

            while True:
                unvisited = [i for i in range(1, len(G.nodes)) if not G.nodes[i].visited]
                if not unvisited:
                    break

                probabilities = calculate_probabilities(current_node, unvisited, current_time, current_capacity)
                if not probabilities.any():  # No valid moves
                    break

                next_node = random.choices(unvisited, weights=probabilities)[0]
                travel_time = G.distance_matrix[current_node][next_node]
                arrival_time = current_time + travel_time

                # Validate constraints
                if (current_capacity + G.nodes[next_node].demand <= capacity_max
                        and arrival_time <= G.nodes[next_node].due_date):
                    if arrival_time < G.nodes[next_node].ready_time:
                        wait_time = G.nodes[next_node].ready_time - arrival_time
                    else:
                        wait_time = 0
                    current_time = arrival_time + wait_time + G.nodes[next_node].service_time
                    current_capacity += G.nodes[next_node].demand
                    route.append(next_node)
                    G.nodes[next_node].visited = True
                    current_node = next_node
                else:
                    break  # No valid moves; end route

            # Return to depot
            current_time = current_time + G.distance_matrix[route[-1]][0]
            route.append(0)
            routes.append(route)
            back_time.append(current_time)
        if current_time > G.nodes[0].due_date:
            print("invalide route")
        return (routes,back_time)

    def calculate_total_distance(route):
        """
        Calculate the total distance of a given route using the distance matrix.
        """
        total_distance = 0
        for i in range(len(route) - 1):
            current_node = route[i]
            next_node = route[i + 1]
            total_distance += G.distance_matrix[current_node][next_node]
        return total_distance

    
    def calculate_cost(routes):
        total_cost = 0
        num_vehicles = len(routes)
        if num_vehicles > G.num_vehicles:  # Penalty for exceeding vehicle limits
            total_cost += 10000 * (num_vehicles - G.num_vehicles)
        for route in routes:
            total_cost += calculate_total_distance(route)
        total_cost = total_cost + num_vehicles*1000
        return total_cost



    def update_pheromones(all_solutions, ph_matrix, evaporation_rate=0.5):
        # Evaporate pheromones
        for i in range(len(ph_matrix)):
            for j in range(len(ph_matrix[i])):
                ph_matrix[i][j] *= (1 - evaporation_rate)
                ph_matrix[i][j] = max(ph_matrix[i][j], 1e-5)  # Prevent near-zero pheromones

        # Deposit pheromones for each solution
        for solution in all_solutions:
            routes = solution  # Each solution is a list of routes
            for route in routes:
                route_distance = calculate_total_distance(route)
                pheromone_deposit = q / max(route_distance, 1e-5)  # Prevent division by zero
                for i in range(len(route) - 1):
                    a, b = route[i], route[i + 1]
                    ph_matrix[a][b] += pheromone_deposit
                    ph_matrix[b][a] = ph_matrix[a][b]  # Ensure symmetry



    # Main ACO loop
    for iteration in range(num_iterations):
        all_solutions = []
        all_costs = []

        for _ in range(num_ants):
            solution = construct_solution()
            cost = calculate_cost(solution[0])
            all_solutions.append(solution[0])
            all_costs.append(cost)

            if cost < best_cost:
                best_cost = cost
                best_solution = solution

        if len(best_solution[0]) <= G.num_vehicles:
            best_length = best_cost - (len(best_solution[0])*1000)
        else:
            best_length = best_cost - (G.num_vehicles*1000) - (len(best_solution[0]) - G.num_vehicles)*10000
        # Update pheromones with all solutions
        update_pheromones(all_solutions, G.pheromone_matrix)
        print(f"Iteration {iteration + 1}/{num_iterations}: Best cost = {round(best_cost,2)}, Best length = {round(best_length,2)}, Latest back time = {round(max(best_solution[1]),2)}")
        

    return best_solution[0],best_length, best_cost, max(best_solution[1])

def plot_solution(graph, solution, filename):
    """
    Plot the solution of the VRP problem.
    Args:
        graph: Graph object containing node information.
        solution: List of routes (e.g., [[0, 1, 3, 0], [0, 2, 4, 0], ...]).
    """
    # Extract node coordinates
    x_coords = [node.x for node in graph.nodes]
    y_coords = [node.y for node in graph.nodes]

    # Create the plot
    plt.figure(figsize=(10, 8))

    # Plot all nodes
    plt.scatter(x_coords, y_coords, color="grey", label="Customers", marker=".", zorder=5)
    
    # Highlight the depot (node 0)
    plt.scatter(x_coords[0], y_coords[0], color="black", label="Depot", marker="D", zorder=5, s=100)

    # Annotate each node with its ID
    for node in graph.nodes:
        plt.text(node.x, node.y, f"{node.id}", fontsize=8, ha="right", va="bottom")

    # Plot each route
    for route in solution:
        route_coords_x = [x_coords[i] for i in route]
        route_coords_y = [y_coords[i] for i in route]
        plt.plot(route_coords_x, route_coords_y, label=f"Route {solution.index(route) + 1}")

    # Customize the plot
    plt.title("Vehicle Routing Problem Solution\n" + filename)
    plt.xlabel("X Coordinate")
    plt.ylabel("Y Coordinate")
    plt.legend()
    plt.grid()
    plt.show()

# %%
G = Graph(vehicle_data, customer_data)

print("Depot closing time: " + str(G.nodes[0].due_date))

# Run ACO
best_solution_data,best_length, best_cost,best_time = aco_vrp(
    G,
    num_ants=50, num_iterations=100, alpha=1.5, beta=2.5, evaporation_rate=0.5, q=100
)

print("\n-----------------------------------------------------------")
print("Best cost: " + str(best_cost), "\nBest length: " + str(best_length),"\Latest back time: " + str(best_time), " \nNumber of vehicle: " + str(len(best_solution_data)))
print("-----------------------------------------------------------\n")

i = 1
for route in best_solution_data:
    print("Route " + str(i) + ": " + str(route))
    i = i + 1

# Call the plotting function with the best solution
plot_solution(G, best_solution_data, dataset_name)
# Out:
# C:\Users\Axel\AppData\Local\Temp\ipykernel_16824\3504090478.py:27: RuntimeWarning: divide by zero encountered in divide
#   self.heuristic_matrix = 1 / self.distance_matrix
# Depot closing time: 1236
# Iteration 1/100: Best cost = 20524.66, Best length = 2524.66, Latest back time = 1095.21
# Iteration 2/100: Best cost = 14629.72, Best length = 1629.72, Latest back time = 1082.03
# Iteration 3/100: Best cost = 14629.72, Best length = 1629.72, Latest back time = 1082.03
# Iteration 4/100: Best cost = 13698.78, Best length = 1698.78, Latest back time = 1082.03
# Iteration 5/100: Best cost = 13698.78, Best length = 1698.78, Latest back time = 1082.03
# Iteration 6/100: Best cost = 13435.73, Best length = 1435.73, Latest back time = 1082.03
# Iteration 7/100: Best cost = 13435.73, Best length = 1435.73, Latest back time = 1082.03
# Iteration 8/100: Best cost = 13435.73, Best length = 1435.73, Latest back time = 1082.03
# Iteration 9/100: Best cost = 13435.73, Best length = 1435.73, Latest back time = 1082.03
# Iteration 10/100: Best cost = 13435.73, Best length = 1435.73, Latest back time = 1082.03
# Iteration 11/100: Best cost = 13435.73, Best length = 1435.73, Latest back time = 1082.03
# Iteration 12/100: Best cost = 13435.73, Best length = 1435.73, Latest back time = 1082.03
# Iteration 13/100: Best cost = 13435.73, Best length = 1435.73, Latest back time = 1082.03
# Iteration 14/100: Best cost = 13435.73, Best length = 1435.73, Latest back time = 1082.03
# Iteration 15/100: Best cost = 13435.73, Best length = 1435.73, Latest back time = 1082.03
# Iteration 16/100: Best cost = 13435.73, Best length = 1435.73, Latest back time = 1082.03
# Iteration 17/100: Best cost = 13283.08, Best length = 1283.08, Latest back time = 1082.03
# Iteration 18/100: Best cost = 13283.08, Best length = 1283.08, Latest back time = 1082.03
# Iteration 19/100: Best cost = 13283.08, Best length = 1283.08, Latest back time = 1082.03
# Iteration 20/100: Best cost = 13283.08, Best length = 1283.08, Latest back time = 1082.03
# Iteration 21/100: Best cost = 13283.08, Best length = 1283.08, Latest back time = 1082.03
# Iteration 22/100: Best cost = 13283.08, Best length = 1283.08, Latest back time = 1082.03
# Iteration 23/100: Best cost = 13283.08, Best length = 1283.08, Latest back time = 1082.03
# Iteration 24/100: Best cost = 13283.08, Best length = 1283.08, Latest back time = 1082.03
# Iteration 25/100: Best cost = 13283.08, Best length = 1283.08, Latest back time = 1082.03
# Iteration 26/100: Best cost = 13283.08, Best length = 1283.08, Latest back time = 1082.03
# Iteration 27/100: Best cost = 13283.08, Best length = 1283.08, Latest back time = 1082.03
# Iteration 28/100: Best cost = 13283.08, Best length = 1283.08, Latest back time = 1082.03
# Iteration 29/100: Best cost = 13283.08, Best length = 1283.08, Latest back time = 1082.03
# Iteration 30/100: Best cost = 13283.08, Best length = 1283.08, Latest back time = 1082.03
# Iteration 31/100: Best cost = 13283.08, Best length = 1283.08, Latest back time = 1082.03
# Iteration 32/100: Best cost = 13283.08, Best length = 1283.08, Latest back time = 1082.03
# Iteration 33/100: Best cost = 13283.08, Best length = 1283.08, Latest back time = 1082.03
# Iteration 34/100: Best cost = 13283.08, Best length = 1283.08, Latest back time = 1082.03
# Iteration 35/100: Best cost = 13283.08, Best length = 1283.08, Latest back time = 1082.03
# Iteration 36/100: Best cost = 13283.08, Best length = 1283.08, Latest back time = 1082.03
# Iteration 37/100: Best cost = 13283.08, Best length = 1283.08, Latest back time = 1082.03
# Iteration 38/100: Best cost = 13283.08, Best length = 1283.08, Latest back time = 1082.03
# Iteration 39/100: Best cost = 13283.08, Best length = 1283.08, Latest back time = 1082.03
# Iteration 40/100: Best cost = 13260.53, Best length = 1260.53, Latest back time = 1082.03
# Iteration 41/100: Best cost = 13260.53, Best length = 1260.53, Latest back time = 1082.03
# Iteration 42/100: Best cost = 13260.53, Best length = 1260.53, Latest back time = 1082.03
# Iteration 43/100: Best cost = 13260.53, Best length = 1260.53, Latest back time = 1082.03
# Iteration 44/100: Best cost = 13260.53, Best length = 1260.53, Latest back time = 1082.03
# Iteration 45/100: Best cost = 13260.53, Best length = 1260.53, Latest back time = 1082.03
# Iteration 46/100: Best cost = 13260.53, Best length = 1260.53, Latest back time = 1082.03
# Iteration 47/100: Best cost = 13260.53, Best length = 1260.53, Latest back time = 1082.03
# Iteration 48/100: Best cost = 13260.53, Best length = 1260.53, Latest back time = 1082.03
# Iteration 49/100: Best cost = 13260.53, Best length = 1260.53, Latest back time = 1082.03
# Iteration 50/100: Best cost = 13260.53, Best length = 1260.53, Latest back time = 1082.03
# Iteration 51/100: Best cost = 13260.53, Best length = 1260.53, Latest back time = 1082.03
# Iteration 52/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 53/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 54/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 55/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 56/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 57/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 58/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 59/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 60/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 61/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 62/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 63/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 64/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 65/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 66/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 67/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 68/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 69/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 70/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 71/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 72/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 73/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 74/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 75/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 76/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 77/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 78/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 79/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 80/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 81/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 82/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 83/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 84/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 85/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 86/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 87/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 88/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 89/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 90/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 91/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 92/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 93/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 94/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 95/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 96/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 97/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 98/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 99/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
# Iteration 100/100: Best cost = 12468.09, Best length = 1468.09, Latest back time = 1082.03
#
# -----------------------------------------------------------
# Best cost: 12468.090284128366
# Best length: 1468.090284128366 \Latest back time: 1082.02775637732
# Number of vehicle: 11
# -----------------------------------------------------------
#
# Route 1: [0, 90, 87, 86, 84, 85, 88, 89, 91, 2, 1, 75, 0]
# Route 2: [0, 10, 11, 9, 6, 4, 99, 22, 21, 52, 49, 47, 0]
# Route 3: [0, 20, 24, 25, 27, 28, 26, 23, 34, 66, 69, 0]
# Route 4: [0, 67, 65, 63, 62, 74, 72, 61, 64, 68, 80, 50, 0]
# Route 5: [0, 32, 33, 31, 35, 37, 38, 39, 36, 59, 51, 0]
# Route 6: [0, 98, 96, 95, 94, 92, 93, 97, 100, 12, 0]
# Route 7: [0, 13, 17, 18, 19, 15, 16, 14, 79, 0]
# Route 8: [0, 43, 42, 41, 40, 44, 45, 48, 0]
# Route 9: [0, 5, 3, 7, 8, 83, 82, 70, 73, 77, 0]
# Route 10: [0, 81, 78, 76, 71, 56, 58, 60, 0]
# Route 11: [0, 57, 55, 54, 53, 29, 30, 46, 0]

# %% [markdown]
# # This solution above ...

# %%
print("Use "+str(len(best_solution_data))+" vehicles")
# Out:
# Use 11 vehicles

# %%
print("Has a total cost of: " + str(best_cost))
# Out:
# Has a total cost of: 12468.090284128366

# %% [markdown]
# While Total Cost represent 1 per distance unit, 1 000 per authorized vehicle, 10 000 per unavailable vehicle.

# %%
print("Has a latest back time of: " + str(best_time))
print("While the depot closing time is: " + str(G.nodes[0].due_date))
# Out:
# Has a latest back time of: 1082.02775637732
# While the depot closing time is: 1236

# %%
print("Has a total distance of: " + str(best_length))
# Out:
# Has a total distance of: 1468.090284128366
