# %%
file_path = 'data.txt'

# Initialize lists to store vehicle and customer data
vehicle_data = []
customer_data = []

# Read data line by line
with open(file_path, 'r') as file:
    lines = file.readlines()
    
    # Parse vehicle data
    vehicle_info_start = lines.index('VEHICLE\n') + 2
    vehicle_info_end = lines.index('CUSTOMER\n')
    vehicle_line = lines[vehicle_info_start].strip().split()
    
    # Store vehicle data as a dictionary in a list
    vehicle_data.append({
        'NUMBER': int(vehicle_line[0]),
        'CAPACITY': int(vehicle_line[1])
    })
    
    # Parse customer data
    customer_info_start = vehicle_info_end + 2
    for line in lines[customer_info_start:]:
        if line.strip():  # Skip any empty lines
            parts = line.strip().split()
            customer_data.append({
                'CUST_NO': int(parts[0]),
                'XCOORD': int(parts[1]),
                'YCOORD': int(parts[2]),
                'DEMAND': int(parts[3]),
                'READY_TIME': int(parts[4]),
                'DUE_DATE': int(parts[5]),
                'SERVICE_TIME': int(parts[6])
            })

# Display the parsed data
print("Vehicle Data:")
print(vehicle_data)
print("\nCustomer Data:")
for customer in customer_data:  # Show first 5 customers for brevity
    print(customer)
# Out:
# Vehicle Data:
# [{'NUMBER': 25, 'CAPACITY': 200}]
#
# Customer Data:
# {'CUST_NO': 0, 'XCOORD': 40, 'YCOORD': 50, 'DEMAND': 0, 'READY_TIME': 0, 'DUE_DATE': 1236, 'SERVICE_TIME': 0}
# {'CUST_NO': 1, 'XCOORD': 45, 'YCOORD': 68, 'DEMAND': 10, 'READY_TIME': 912, 'DUE_DATE': 967, 'SERVICE_TIME': 90}
# {'CUST_NO': 2, 'XCOORD': 45, 'YCOORD': 70, 'DEMAND': 30, 'READY_TIME': 825, 'DUE_DATE': 870, 'SERVICE_TIME': 90}
# {'CUST_NO': 3, 'XCOORD': 42, 'YCOORD': 66, 'DEMAND': 10, 'READY_TIME': 65, 'DUE_DATE': 146, 'SERVICE_TIME': 90}
# {'CUST_NO': 4, 'XCOORD': 42, 'YCOORD': 68, 'DEMAND': 10, 'READY_TIME': 727, 'DUE_DATE': 782, 'SERVICE_TIME': 90}
# {'CUST_NO': 5, 'XCOORD': 42, 'YCOORD': 65, 'DEMAND': 10, 'READY_TIME': 15, 'DUE_DATE': 67, 'SERVICE_TIME': 90}
# {'CUST_NO': 6, 'XCOORD': 40, 'YCOORD': 69, 'DEMAND': 20, 'READY_TIME': 621, 'DUE_DATE': 702, 'SERVICE_TIME': 90}
# {'CUST_NO': 7, 'XCOORD': 40, 'YCOORD': 66, 'DEMAND': 20, 'READY_TIME': 170, 'DUE_DATE': 225, 'SERVICE_TIME': 90}
# {'CUST_NO': 8, 'XCOORD': 38, 'YCOORD': 68, 'DEMAND': 20, 'READY_TIME': 255, 'DUE_DATE': 324, 'SERVICE_TIME': 90}
# {'CUST_NO': 9, 'XCOORD': 38, 'YCOORD': 70, 'DEMAND': 10, 'READY_TIME': 534, 'DUE_DATE': 605, 'SERVICE_TIME': 90}
# {'CUST_NO': 10, 'XCOORD': 35, 'YCOORD': 66, 'DEMAND': 10, 'READY_TIME': 357, 'DUE_DATE': 410, 'SERVICE_TIME': 90}
# {'CUST_NO': 11, 'XCOORD': 35, 'YCOORD': 69, 'DEMAND': 10, 'READY_TIME': 448, 'DUE_DATE': 505, 'SERVICE_TIME': 90}
# {'CUST_NO': 12, 'XCOORD': 25, 'YCOORD': 85, 'DEMAND': 20, 'READY_TIME': 652, 'DUE_DATE': 721, 'SERVICE_TIME': 90}
# {'CUST_NO': 13, 'XCOORD': 22, 'YCOORD': 75, 'DEMAND': 30, 'READY_TIME': 30, 'DUE_DATE': 92, 'SERVICE_TIME': 90}
# {'CUST_NO': 14, 'XCOORD': 22, 'YCOORD': 85, 'DEMAND': 10, 'READY_TIME': 567, 'DUE_DATE': 620, 'SERVICE_TIME': 90}
# {'CUST_NO': 15, 'XCOORD': 20, 'YCOORD': 80, 'DEMAND': 40, 'READY_TIME': 384, 'DUE_DATE': 429, 'SERVICE_TIME': 90}
# {'CUST_NO': 16, 'XCOORD': 20, 'YCOORD': 85, 'DEMAND': 40, 'READY_TIME': 475, 'DUE_DATE': 528, 'SERVICE_TIME': 90}
# {'CUST_NO': 17, 'XCOORD': 18, 'YCOORD': 75, 'DEMAND': 20, 'READY_TIME': 99, 'DUE_DATE': 148, 'SERVICE_TIME': 90}
# {'CUST_NO': 18, 'XCOORD': 15, 'YCOORD': 75, 'DEMAND': 20, 'READY_TIME': 179, 'DUE_DATE': 254, 'SERVICE_TIME': 90}
# {'CUST_NO': 19, 'XCOORD': 15, 'YCOORD': 80, 'DEMAND': 10, 'READY_TIME': 278, 'DUE_DATE': 345, 'SERVICE_TIME': 90}
# {'CUST_NO': 20, 'XCOORD': 30, 'YCOORD': 50, 'DEMAND': 10, 'READY_TIME': 10, 'DUE_DATE': 73, 'SERVICE_TIME': 90}
# {'CUST_NO': 21, 'XCOORD': 30, 'YCOORD': 52, 'DEMAND': 20, 'READY_TIME': 914, 'DUE_DATE': 965, 'SERVICE_TIME': 90}
# {'CUST_NO': 22, 'XCOORD': 28, 'YCOORD': 52, 'DEMAND': 20, 'READY_TIME': 812, 'DUE_DATE': 883, 'SERVICE_TIME': 90}
# {'CUST_NO': 23, 'XCOORD': 28, 'YCOORD': 55, 'DEMAND': 10, 'READY_TIME': 732, 'DUE_DATE': 777, 'SERVICE_TIME': 90}
# {'CUST_NO': 24, 'XCOORD': 25, 'YCOORD': 50, 'DEMAND': 10, 'READY_TIME': 65, 'DUE_DATE': 144, 'SERVICE_TIME': 90}
# {'CUST_NO': 25, 'XCOORD': 25, 'YCOORD': 52, 'DEMAND': 40, 'READY_TIME': 169, 'DUE_DATE': 224, 'SERVICE_TIME': 90}
# {'CUST_NO': 26, 'XCOORD': 25, 'YCOORD': 55, 'DEMAND': 10, 'READY_TIME': 622, 'DUE_DATE': 701, 'SERVICE_TIME': 90}
# {'CUST_NO': 27, 'XCOORD': 23, 'YCOORD': 52, 'DEMAND': 10, 'READY_TIME': 261, 'DUE_DATE': 316, 'SERVICE_TIME': 90}
# {'CUST_NO': 28, 'XCOORD': 23, 'YCOORD': 55, 'DEMAND': 20, 'READY_TIME': 546, 'DUE_DATE': 593, 'SERVICE_TIME': 90}
# {'CUST_NO': 29, 'XCOORD': 20, 'YCOORD': 50, 'DEMAND': 10, 'READY_TIME': 358, 'DUE_DATE': 405, 'SERVICE_TIME': 90}
# {'CUST_NO': 30, 'XCOORD': 20, 'YCOORD': 55, 'DEMAND': 10, 'READY_TIME': 449, 'DUE_DATE': 504, 'SERVICE_TIME': 90}
# {'CUST_NO': 31, 'XCOORD': 10, 'YCOORD': 35, 'DEMAND': 20, 'READY_TIME': 200, 'DUE_DATE': 237, 'SERVICE_TIME': 90}
# {'CUST_NO': 32, 'XCOORD': 10, 'YCOORD': 40, 'DEMAND': 30, 'READY_TIME': 31, 'DUE_DATE': 100, 'SERVICE_TIME': 90}
# {'CUST_NO': 33, 'XCOORD': 8, 'YCOORD': 40, 'DEMAND': 40, 'READY_TIME': 87, 'DUE_DATE': 158, 'SERVICE_TIME': 90}
# {'CUST_NO': 34, 'XCOORD': 8, 'YCOORD': 45, 'DEMAND': 20, 'READY_TIME': 751, 'DUE_DATE': 816, 'SERVICE_TIME': 90}
# {'CUST_NO': 35, 'XCOORD': 5, 'YCOORD': 35, 'DEMAND': 10, 'READY_TIME': 283, 'DUE_DATE': 344, 'SERVICE_TIME': 90}
# {'CUST_NO': 36, 'XCOORD': 5, 'YCOORD': 45, 'DEMAND': 10, 'READY_TIME': 665, 'DUE_DATE': 716, 'SERVICE_TIME': 90}
# {'CUST_NO': 37, 'XCOORD': 2, 'YCOORD': 40, 'DEMAND': 20, 'READY_TIME': 383, 'DUE_DATE': 434, 'SERVICE_TIME': 90}
# {'CUST_NO': 38, 'XCOORD': 0, 'YCOORD': 40, 'DEMAND': 30, 'READY_TIME': 479, 'DUE_DATE': 522, 'SERVICE_TIME': 90}
# {'CUST_NO': 39, 'XCOORD': 0, 'YCOORD': 45, 'DEMAND': 20, 'READY_TIME': 567, 'DUE_DATE': 624, 'SERVICE_TIME': 90}
# {'CUST_NO': 40, 'XCOORD': 35, 'YCOORD': 30, 'DEMAND': 10, 'READY_TIME': 264, 'DUE_DATE': 321, 'SERVICE_TIME': 90}
# {'CUST_NO': 41, 'XCOORD': 35, 'YCOORD': 32, 'DEMAND': 10, 'READY_TIME': 166, 'DUE_DATE': 235, 'SERVICE_TIME': 90}
# {'CUST_NO': 42, 'XCOORD': 33, 'YCOORD': 32, 'DEMAND': 20, 'READY_TIME': 68, 'DUE_DATE': 149, 'SERVICE_TIME': 90}
# {'CUST_NO': 43, 'XCOORD': 33, 'YCOORD': 35, 'DEMAND': 10, 'READY_TIME': 16, 'DUE_DATE': 80, 'SERVICE_TIME': 90}
# {'CUST_NO': 44, 'XCOORD': 32, 'YCOORD': 30, 'DEMAND': 10, 'READY_TIME': 359, 'DUE_DATE': 412, 'SERVICE_TIME': 90}
# {'CUST_NO': 45, 'XCOORD': 30, 'YCOORD': 30, 'DEMAND': 10, 'READY_TIME': 541, 'DUE_DATE': 600, 'SERVICE_TIME': 90}
# {'CUST_NO': 46, 'XCOORD': 30, 'YCOORD': 32, 'DEMAND': 30, 'READY_TIME': 448, 'DUE_DATE': 509, 'SERVICE_TIME': 90}
# {'CUST_NO': 47, 'XCOORD': 30, 'YCOORD': 35, 'DEMAND': 10, 'READY_TIME': 1054, 'DUE_DATE': 1127, 'SERVICE_TIME': 90}
# {'CUST_NO': 48, 'XCOORD': 28, 'YCOORD': 30, 'DEMAND': 10, 'READY_TIME': 632, 'DUE_DATE': 693, 'SERVICE_TIME': 90}
# {'CUST_NO': 49, 'XCOORD': 28, 'YCOORD': 35, 'DEMAND': 10, 'READY_TIME': 1001, 'DUE_DATE': 1066, 'SERVICE_TIME': 90}
# {'CUST_NO': 50, 'XCOORD': 26, 'YCOORD': 32, 'DEMAND': 10, 'READY_TIME': 815, 'DUE_DATE': 880, 'SERVICE_TIME': 90}
# {'CUST_NO': 51, 'XCOORD': 25, 'YCOORD': 30, 'DEMAND': 10, 'READY_TIME': 725, 'DUE_DATE': 786, 'SERVICE_TIME': 90}
# {'CUST_NO': 52, 'XCOORD': 25, 'YCOORD': 35, 'DEMAND': 10, 'READY_TIME': 912, 'DUE_DATE': 969, 'SERVICE_TIME': 90}
# {'CUST_NO': 53, 'XCOORD': 44, 'YCOORD': 5, 'DEMAND': 20, 'READY_TIME': 286, 'DUE_DATE': 347, 'SERVICE_TIME': 90}
# {'CUST_NO': 54, 'XCOORD': 42, 'YCOORD': 10, 'DEMAND': 40, 'READY_TIME': 186, 'DUE_DATE': 257, 'SERVICE_TIME': 90}
# {'CUST_NO': 55, 'XCOORD': 42, 'YCOORD': 15, 'DEMAND': 10, 'READY_TIME': 95, 'DUE_DATE': 158, 'SERVICE_TIME': 90}
# {'CUST_NO': 56, 'XCOORD': 40, 'YCOORD': 5, 'DEMAND': 30, 'READY_TIME': 385, 'DUE_DATE': 436, 'SERVICE_TIME': 90}
# {'CUST_NO': 57, 'XCOORD': 40, 'YCOORD': 15, 'DEMAND': 40, 'READY_TIME': 35, 'DUE_DATE': 87, 'SERVICE_TIME': 90}
# {'CUST_NO': 58, 'XCOORD': 38, 'YCOORD': 5, 'DEMAND': 30, 'READY_TIME': 471, 'DUE_DATE': 534, 'SERVICE_TIME': 90}
# {'CUST_NO': 59, 'XCOORD': 38, 'YCOORD': 15, 'DEMAND': 10, 'READY_TIME': 651, 'DUE_DATE': 740, 'SERVICE_TIME': 90}
# {'CUST_NO': 60, 'XCOORD': 35, 'YCOORD': 5, 'DEMAND': 20, 'READY_TIME': 562, 'DUE_DATE': 629, 'SERVICE_TIME': 90}
# {'CUST_NO': 61, 'XCOORD': 50, 'YCOORD': 30, 'DEMAND': 10, 'READY_TIME': 531, 'DUE_DATE': 610, 'SERVICE_TIME': 90}
# {'CUST_NO': 62, 'XCOORD': 50, 'YCOORD': 35, 'DEMAND': 20, 'READY_TIME': 262, 'DUE_DATE': 317, 'SERVICE_TIME': 90}
# {'CUST_NO': 63, 'XCOORD': 50, 'YCOORD': 40, 'DEMAND': 50, 'READY_TIME': 171, 'DUE_DATE': 218, 'SERVICE_TIME': 90}
# {'CUST_NO': 64, 'XCOORD': 48, 'YCOORD': 30, 'DEMAND': 10, 'READY_TIME': 632, 'DUE_DATE': 693, 'SERVICE_TIME': 90}
# {'CUST_NO': 65, 'XCOORD': 48, 'YCOORD': 40, 'DEMAND': 10, 'READY_TIME': 76, 'DUE_DATE': 129, 'SERVICE_TIME': 90}
# {'CUST_NO': 66, 'XCOORD': 47, 'YCOORD': 35, 'DEMAND': 10, 'READY_TIME': 826, 'DUE_DATE': 875, 'SERVICE_TIME': 90}
# {'CUST_NO': 67, 'XCOORD': 47, 'YCOORD': 40, 'DEMAND': 10, 'READY_TIME': 12, 'DUE_DATE': 77, 'SERVICE_TIME': 90}
# {'CUST_NO': 68, 'XCOORD': 45, 'YCOORD': 30, 'DEMAND': 10, 'READY_TIME': 734, 'DUE_DATE': 777, 'SERVICE_TIME': 90}
# {'CUST_NO': 69, 'XCOORD': 45, 'YCOORD': 35, 'DEMAND': 10, 'READY_TIME': 916, 'DUE_DATE': 969, 'SERVICE_TIME': 90}
# {'CUST_NO': 70, 'XCOORD': 95, 'YCOORD': 30, 'DEMAND': 30, 'READY_TIME': 387, 'DUE_DATE': 456, 'SERVICE_TIME': 90}
# {'CUST_NO': 71, 'XCOORD': 95, 'YCOORD': 35, 'DEMAND': 20, 'READY_TIME': 293, 'DUE_DATE': 360, 'SERVICE_TIME': 90}
# {'CUST_NO': 72, 'XCOORD': 53, 'YCOORD': 30, 'DEMAND': 10, 'READY_TIME': 450, 'DUE_DATE': 505, 'SERVICE_TIME': 90}
# {'CUST_NO': 73, 'XCOORD': 92, 'YCOORD': 30, 'DEMAND': 10, 'READY_TIME': 478, 'DUE_DATE': 551, 'SERVICE_TIME': 90}
# {'CUST_NO': 74, 'XCOORD': 53, 'YCOORD': 35, 'DEMAND': 50, 'READY_TIME': 353, 'DUE_DATE': 412, 'SERVICE_TIME': 90}
# {'CUST_NO': 75, 'XCOORD': 45, 'YCOORD': 65, 'DEMAND': 20, 'READY_TIME': 997, 'DUE_DATE': 1068, 'SERVICE_TIME': 90}
# {'CUST_NO': 76, 'XCOORD': 90, 'YCOORD': 35, 'DEMAND': 10, 'READY_TIME': 203, 'DUE_DATE': 260, 'SERVICE_TIME': 90}
# {'CUST_NO': 77, 'XCOORD': 88, 'YCOORD': 30, 'DEMAND': 10, 'READY_TIME': 574, 'DUE_DATE': 643, 'SERVICE_TIME': 90}
# {'CUST_NO': 78, 'XCOORD': 88, 'YCOORD': 35, 'DEMAND': 20, 'READY_TIME': 109, 'DUE_DATE': 170, 'SERVICE_TIME': 90}
# {'CUST_NO': 79, 'XCOORD': 87, 'YCOORD': 30, 'DEMAND': 10, 'READY_TIME': 668, 'DUE_DATE': 731, 'SERVICE_TIME': 90}
# {'CUST_NO': 80, 'XCOORD': 85, 'YCOORD': 25, 'DEMAND': 10, 'READY_TIME': 769, 'DUE_DATE': 820, 'SERVICE_TIME': 90}
# {'CUST_NO': 81, 'XCOORD': 85, 'YCOORD': 35, 'DEMAND': 30, 'READY_TIME': 47, 'DUE_DATE': 124, 'SERVICE_TIME': 90}
# {'CUST_NO': 82, 'XCOORD': 75, 'YCOORD': 55, 'DEMAND': 20, 'READY_TIME': 369, 'DUE_DATE': 420, 'SERVICE_TIME': 90}
# {'CUST_NO': 83, 'XCOORD': 72, 'YCOORD': 55, 'DEMAND': 10, 'READY_TIME': 265, 'DUE_DATE': 338, 'SERVICE_TIME': 90}
# {'CUST_NO': 84, 'XCOORD': 70, 'YCOORD': 58, 'DEMAND': 20, 'READY_TIME': 458, 'DUE_DATE': 523, 'SERVICE_TIME': 90}
# {'CUST_NO': 85, 'XCOORD': 68, 'YCOORD': 60, 'DEMAND': 30, 'READY_TIME': 555, 'DUE_DATE': 612, 'SERVICE_TIME': 90}
# {'CUST_NO': 86, 'XCOORD': 66, 'YCOORD': 55, 'DEMAND': 10, 'READY_TIME': 173, 'DUE_DATE': 238, 'SERVICE_TIME': 90}
# {'CUST_NO': 87, 'XCOORD': 65, 'YCOORD': 55, 'DEMAND': 20, 'READY_TIME': 85, 'DUE_DATE': 144, 'SERVICE_TIME': 90}
# {'CUST_NO': 88, 'XCOORD': 65, 'YCOORD': 60, 'DEMAND': 30, 'READY_TIME': 645, 'DUE_DATE': 708, 'SERVICE_TIME': 90}
# {'CUST_NO': 89, 'XCOORD': 63, 'YCOORD': 58, 'DEMAND': 10, 'READY_TIME': 737, 'DUE_DATE': 802, 'SERVICE_TIME': 90}
# {'CUST_NO': 90, 'XCOORD': 60, 'YCOORD': 55, 'DEMAND': 10, 'READY_TIME': 20, 'DUE_DATE': 84, 'SERVICE_TIME': 90}
# {'CUST_NO': 91, 'XCOORD': 60, 'YCOORD': 60, 'DEMAND': 10, 'READY_TIME': 836, 'DUE_DATE': 889, 'SERVICE_TIME': 90}
# {'CUST_NO': 92, 'XCOORD': 67, 'YCOORD': 85, 'DEMAND': 20, 'READY_TIME': 368, 'DUE_DATE': 441, 'SERVICE_TIME': 90}
# {'CUST_NO': 93, 'XCOORD': 65, 'YCOORD': 85, 'DEMAND': 40, 'READY_TIME': 475, 'DUE_DATE': 518, 'SERVICE_TIME': 90}
# {'CUST_NO': 94, 'XCOORD': 65, 'YCOORD': 82, 'DEMAND': 10, 'READY_TIME': 285, 'DUE_DATE': 336, 'SERVICE_TIME': 90}
# {'CUST_NO': 95, 'XCOORD': 62, 'YCOORD': 80, 'DEMAND': 30, 'READY_TIME': 196, 'DUE_DATE': 239, 'SERVICE_TIME': 90}
# {'CUST_NO': 96, 'XCOORD': 60, 'YCOORD': 80, 'DEMAND': 10, 'READY_TIME': 95, 'DUE_DATE': 156, 'SERVICE_TIME': 90}
# {'CUST_NO': 97, 'XCOORD': 60, 'YCOORD': 85, 'DEMAND': 30, 'READY_TIME': 561, 'DUE_DATE': 622, 'SERVICE_TIME': 90}
# {'CUST_NO': 98, 'XCOORD': 58, 'YCOORD': 75, 'DEMAND': 20, 'READY_TIME': 30, 'DUE_DATE': 84, 'SERVICE_TIME': 90}
# {'CUST_NO': 99, 'XCOORD': 55, 'YCOORD': 80, 'DEMAND': 10, 'READY_TIME': 743, 'DUE_DATE': 820, 'SERVICE_TIME': 90}
# {'CUST_NO': 100, 'XCOORD': 55, 'YCOORD': 85, 'DEMAND': 20, 'READY_TIME': 647, 'DUE_DATE': 726, 'SERVICE_TIME': 90}

# %% [markdown]
# 1. Data Structures
# From your parsed data:
#
# vehicle_data: Contains the number of vehicles and their capacities.
# customer_data: Includes customer coordinates, demands, time windows, and service times.
# We'll convert this into a format usable for the GAH:
#
# Distance Matrix: Precompute the distances between all customers (including the depot).
# Demand, Time Windows, and Service Times: Use them as constraints in the evaluation function.

# %% [markdown]
# 2. Distance Matrix Calculation
# Compute the distance matrix between all customers (and the depot).

# %%
import numpy as np
from math import sqrt

# Compute the distance matrix
def calculate_distance_matrix(customer_data):
    num_customers = len(customer_data)
    distance_matrix = np.zeros((num_customers + 1, num_customers + 1))  # +1 for the depot
    all_points = [(0, 0)] + [(cust['XCOORD'], cust['YCOORD']) for cust in customer_data]  # Depot at (0,0)
    
    for i in range(len(all_points)):
        for j in range(len(all_points)):
            distance_matrix[i][j] = sqrt((all_points[i][0] - all_points[j][0])**2 +
                                         (all_points[i][1] - all_points[j][1])**2)
    return distance_matrix

distance_matrix = calculate_distance_matrix(customer_data)

# %% [markdown]
# 3. Fitness Function
# Define the fitness function to evaluate solutions. This includes:
#
# Total Distance: Sum of all route distances.
# Penalty for Constraints: Add large penalties for capacity and time window violations.

# %%
def evaluate_solution(solution, distance_matrix, vehicle_capacity, customer_data):
    total_cost = 0
    penalty = 0
    is_feasible = True
    
    for route in solution:
        load = 0
        time = 0
        prev_customer = 0
        for customer in route:
            if customer == 0:
                continue
            cust_data = customer_data[customer - 1]
            load += cust_data['DEMAND']
            time = max(time + distance_matrix[prev_customer][customer], cust_data['READY_TIME'])
            if load > vehicle_capacity or time > cust_data['DUE_DATE']:
                is_feasible = False
            time += cust_data['SERVICE_TIME']
            prev_customer = customer
        total_cost += distance_matrix[prev_customer][0]
    
    if not is_feasible:
        penalty += 1e6  # Pénalité élevée pour solutions non faisables
    
    return total_cost + penalty

# %% [markdown]
# 4. Genetic Algorithm Framework
# Here's the main structure of the GAH, incorporating the data you parsed.

# %%
import random

# Parameters
population_size = 50
generations = 100
mutation_rate = 0.15
vehicle_capacity = vehicle_data[0]['CAPACITY']
num_vehicles = vehicle_data[0]['NUMBER']
num_customers = len(customer_data)

# Generate initial population
def create_initial_solution():
    """Générer une solution faisable en respectant les contraintes de capacité et de temps."""
    customers = list(range(1, num_customers + 1))
    random.shuffle(customers)
    solution = []

    for _ in range(num_vehicles):
        route = [0]  # Commence au dépôt
        load = 0
        time = 0
        remaining_customers = []
        
        for customer in customers:
            cust_data = customer_data[customer - 1]
            demand = cust_data['DEMAND']
            ready_time = cust_data['READY_TIME']
            due_date = cust_data['DUE_DATE']
            service_time = cust_data['SERVICE_TIME']
            travel_time = distance_matrix[route[-1]][customer]

            # Vérifie la faisabilité d'ajouter ce client
            arrival_time = max(time + travel_time, ready_time)
            if load + demand <= vehicle_capacity and arrival_time <= due_date:
                route.append(customer)
                load += demand
                time = arrival_time + service_time
            else:
                remaining_customers.append(customer)

        route.append(0)  # Retour au dépôt
        solution.append(route)
        customers = remaining_customers

    # Vérifie si tous les clients ont été servis
    if customers:
        raise ValueError("Impossible de générer une solution initiale faisable avec les véhicules disponibles.")
    
    return solution



# Genetic operators
def crossover(parent1, parent2):
    """Partially Matched Crossover (PMX) avec réparation."""
    child = []
    for route1, route2 in zip(parent1, parent2):
        size = len(route1)
        if size <= 3:  # Cas de routes courtes
            child.append(route1[:])  # Copie directe
        else:
            start, end = sorted(random.sample(range(1, size - 1), 2))
            child_part = route1[start:end]
            child_route = [c for c in route2 if c not in child_part]
            child.append([0] + child_route[:start] + child_part + child_route[start:] + [0])
    return repair_solution(child)



def mutate(solution):
    """Mutation par échange avec réparation."""
    for route in solution:
        if random.random() < mutation_rate:
            i, j = random.sample(range(1, len(route) - 1), 2)
            route[i], route[j] = route[j], route[i]
    return repair_solution(solution)


def local_search(solution):
    """2-opt optimization for routes."""
    for route in solution:
        best_cost = evaluate_solution([route], distance_matrix, vehicle_capacity, customer_data)
        for i in range(1, len(route) - 2):
            for j in range(i + 1, len(route) - 1):
                new_route = route[:i] + route[i:j + 1][::-1] + route[j + 1:]
                new_cost = evaluate_solution([new_route], distance_matrix, vehicle_capacity, customer_data)
                if new_cost < best_cost:
                    route = new_route
                    best_cost = new_cost
    return solution


def repair_solution(solution):
    """Réparer une solution non faisable pour respecter les contraintes."""
    repaired_solution = []
    unassigned_customers = []
    
    for route in solution:
        load = 0
        time = 0
        new_route = [0]  # Commence au dépôt
        
        for customer in route[1:-1]:  # Ignore le dépôt (0)
            cust_data = customer_data[customer - 1]
            demand = cust_data['DEMAND']
            ready_time = cust_data['READY_TIME']
            due_date = cust_data['DUE_DATE']
            service_time = cust_data['SERVICE_TIME']
            travel_time = distance_matrix[new_route[-1]][customer]

            arrival_time = max(time + travel_time, ready_time)
            if load + demand <= vehicle_capacity and arrival_time <= due_date:
                new_route.append(customer)
                load += demand
                time = arrival_time + service_time
            else:
                unassigned_customers.append(customer)
        
        new_route.append(0)  # Retour au dépôt
        repaired_solution.append(new_route)
    
    # Assigne les clients non affectés à de nouveaux véhicules
    while unassigned_customers:
        route = [0]
        load = 0
        time = 0
        remaining_customers = []
        
        for customer in unassigned_customers:
            cust_data = customer_data[customer - 1]
            demand = cust_data['DEMAND']
            ready_time = cust_data['READY_TIME']
            due_date = cust_data['DUE_DATE']
            service_time = cust_data['SERVICE_TIME']
            travel_time = distance_matrix[route[-1]][customer]

            arrival_time = max(time + travel_time, ready_time)
            if load + demand <= vehicle_capacity and arrival_time <= due_date:
                route.append(customer)
                load += demand
                time = arrival_time + service_time
            else:
                remaining_customers.append(customer)
        
        route.append(0)  # Retour au dépôt
        repaired_solution.append(route)
        unassigned_customers = remaining_customers
    
    return repaired_solution


# Main GAH loop
def genetic_algorithm():
    population = [create_initial_solution() for _ in range(population_size)]
    
    for generation in range(generations):
        new_population = []
        for _ in range(population_size // 2):
            parent1, parent2 = random.sample(population, 2)
            child1, child2 = crossover(parent1, parent2), crossover(parent2, parent1)
            child1, child2 = mutate(child1), mutate(child2)
            child1, child2 = local_search(child1), local_search(child2)
            new_population.extend([child1, child2])
        population = sorted(population + new_population, key=lambda sol: evaluate_solution(sol, distance_matrix, vehicle_capacity, customer_data))[:population_size]
    
    best_solution = min(population, key=lambda sol: evaluate_solution(sol, distance_matrix, vehicle_capacity, customer_data))
    best_cost = evaluate_solution(best_solution, distance_matrix, vehicle_capacity, customer_data)
    return best_solution, best_cost

# Run GAH
best_solution, best_cost = genetic_algorithm()
print("Best Solution:", best_solution)
print("Best Cost:", best_cost)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [39], line 171
#     168     return best_solution, best_cost
#     170 # Run GAH
# --> 171 best_solution, best_cost = genetic_algorithm()
#     172 print("Best Solution:", best_solution)
#     173 print("Best Cost:", best_cost)
#
# Cell In [39], line 154, in genetic_algorithm()
#     153 def genetic_algorithm():
# --> 154     population = [create_initial_solution() for _ in range(population_size)]
#     156     for generation in range(generations):
#     157         new_population = []
#
# Cell In [39], line 154, in <listcomp>(.0)
#     153 def genetic_algorithm():
# --> 154     population = [create_initial_solution() for _ in range(population_size)]
#     156     for generation in range(generations):
#     157         new_population = []
#
# Cell In [39], line 47, in create_initial_solution()
#      45 # Vérifie si tous les clients ont été servis
#      46 if customers:
# ---> 47     raise ValueError("Impossible de générer une solution initiale faisable avec les véhicules disponibles.")
#      49 return solution
#
# ValueError: Impossible de générer une solution initiale faisable avec les véhicules disponibles.

# %% [markdown]
# Next Steps
# Visualization: Add a function to plot the routes.
# Dynamic Feasibility Checking: Improve handling of capacity and time window constraints dynamically during solution generation.
# Performance Tuning: Adjust parameters like population size, mutation rate, and local search strategy for optimal results.
